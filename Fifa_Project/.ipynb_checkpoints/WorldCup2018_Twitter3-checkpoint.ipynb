# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import pandas as pd
import numpy as np
import datetime
import json
import logging
import nltk
import nltk.stem
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import operator
import folium
from folium import plugins
import matplotlib.pyplot as plt
import seaborn as sns
import emoji
import re
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
#J
consumer_key = 'awImzJ7cQtYMj5jbeeWenLe8R'
consumer_secret = 'Rnr5qv5DRlhelrLPyF1j1AWLi5aE139k1nd074gaiiEOXiHZfi'
access_token = '999278084774866945-KxBvG48iodCgSj5tDS1El5u7r2lAXX8'
access_secret = 'AXGP5SHhpbJuCLVNbRU5yh6fOIwvxLTZOVdBWysWYbG6L'

# %%
#J2
cnsumer_key = 'pEKQsmgPg9YaetPhGTt7z9tw1'
consumer_secret = 'SHHnGWYIld5eCxWWqUyq7aApedVA4dF1FjvWekbszajcc6Ubdc'
acces_token = '999278084774866945-MjhQGh9zdokdMdCAtkegityA95eLLyt'
acces_secret = '8AAMdWirUtvx99rM3XaeEJ3cnh2B03rvRJeMQB11H5GJc'

# %%
#R
consumer_key = 'qbKANPvBND4cDKzRy7dVv7tFM'
consumer_secret = '9GgohQQOuujfVB90csXGHakbI4wnht09DxwqF0Tc6Qjh21U9uc'
access_token = '999278723659632641-J2BeDRgUL6pyXgxHWA0pscDPuKLALar'
access_secret = '7bdrHnvtEnVSXc71llbbONW8DMLmCw62Mp6FuSjk8rq3u'

# %%
#R2
consumer_key = 'lkJEhnBhutbMfUoJnH0BIQyqD'
consumer_secret = 'v1cbGUgzUGi4q0TAiBhB53pglnJCAcVKv9T12Ftz4ANLGZdkmp'
access_token = '999278723659632641-2mgorBfuXIXYODLzYU6fX43EfT2qFNi'
access_secret = 'ffVohG14AR0zMrudA60S49X9Y0vZjzUUj4xMScOTmMb6B'

# %%
#R3
consumer_key = 'IYifTIDZ1tlcUu1vdPmI2wMYm'
consumer_secret = 'QaxzTwaECgGugwFb4VHl2aGOSPDcgAo0hNVG0je3gpZ2rbsjCp'
access_token = '999278723659632641-AEQAFJdwVVBpMa4SsXLqRN34Fud0bQJ'
access_secret = 'KwdGZYFMRuoZ8uHlJNghqMVHscMBEaMl9k1uzlFbUxIKn'

# %%
logging.basicConfig(filename="fifa.log",level=logging.DEBUG,format="%(asctime)s | %(levelname)s | %(message)s")

# %%
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            
            with open('WorldCup.json', 'a') as f:
                f.write(data)
                logging.debug(data)
                #print(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

# %%
geo_polygone_saint_petersbourg = [29.497997, 59.701434, 30.662548, 60.197935]
geo_polygone_samara = [49.994802, 53.088547, 50.383159, 53.414352]   
geo_polygone_saransk = [45.062645, 54.156444, 45.290509, 54.244795] 
geo_polygone_kazan = [48.849433, 55.685018, 49.284766, 55.915044] 
geo_polygone_lekaterinbourg = [60.434298, 56.675458, 60.840805, 56.940268] 
geo_polygone_moscou = [36.737227, 55.145210, 38.020595, 56.047568] 
geo_polygone_nijni_novgorod = [43.745447, 56.177553, 44.103876, 56.397831]
geo_polygone_volgograd = [44.414738, 48.454773, 44.741175, 48.875449]
geo_polygone_rostov_sur_le_don = [39.410991, 47.137967, 39.849071, 47.380294]
geo_polygone_sotchi = [39.639782, 43.539785, 39.805785, 43.659389]
geo_polygone_kaliningrad = [20.302802, 54.639647, 20.631730, 54.786058]

# %%
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=["футбол", "ФИФА", "Россия 2018", "Россия2018", "Кубок мира","FIFAFanFest",
                             "WM2018","Russia2018WorldCup","World Cup 2018 Russia","World Cup Saint Petersburg",
                             "FIFAFanMatch","Чемпионат мира","ЧМ2018","TeamRussia","Команда Россия"],
                      locations = geo_polygone_saint_petersbourg or geo_polygone_samara or geo_polygone_saransk 
                      or geo_polygone_kazan or geo_polygone_lekaterinbourg or geo_polygone_moscou 
                      or geo_polygone_nijni_novgorod or geo_polygone_volgograd or geo_polygone_rostov_sur_le_don 
                      or geo_polygone_sotchi or geo_polygone_kaliningrad)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\joudj\Anaconda3\lib\logging\__init__.py", line 994, in emit
#     stream.write(msg)
#   File "C:\Users\joudj\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 366-371: character maps to <undefined>
# Call stack:
#   File "C:\Users\joudj\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\joudj\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2856, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-644e6714ee72>", line 8, in <module>
#     or geo_polygone_sotchi or geo_polygone_kaliningrad)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\tweepy\streaming.py", line 450, in filter
#     self._start(async)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\tweepy\streaming.py", line 364, in _start
#     self._run()
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\tweepy\streaming.py", line 250, in _run
#     verify=self.verify)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\requests\sessions.py", line 494, in request
#     prep = self.prepare_request(req)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\requests\sessions.py", line 437, in prepare_request
#     hooks=merge_hooks(request.hooks, self.hooks),
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\requests\models.py", line 309, in prepare
#     self.prepare_auth(auth, url)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\requests\models.py", line 540, in prepare_auth
#     r = auth(self)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\requests_oauthlib\oauth1_auth.py", line 80, in __call__
#     unicode(r.url), unicode(r.method), r.body or '', r.headers)
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\oauthlib\oauth1\rfc5849\__init__.py", line 314, in sign
#     ('oauth_signature', self.get_oauth_signature(request)))
#   File "C:\Users\joudj\Anaconda3\lib\site-packages\oauthlib\oauth1\rfc5849\__init__.py", line 135, in get_oauth_signature
#     log.debug("Collected params: {0}".format(collected_params))
# Message: "Collected params: [('delimited', 'length'), ('oauth_nonce', '164507383559214769401528932916'), ('oauth_timestamp', '1528932916'), ('oauth_version', '1.0'), ('oauth_signature_method', 'HMAC-SHA1'), ('oauth_consumer_key', 'IYifTIDZ1tlcUu1vdPmI2wMYm'), ('oauth_token', '999278723659632641-AEQAFJdwVVBpMa4SsXLqRN34Fud0bQJ'), ('track', 'футбол,ФИФА,Россия 2018,Россия2018,Кубок мира,FIFAFanFest,WM2018,Russia2018WorldCup,World Cup 2018 Russia,World Cup Saint Petersburg,FIFAFanMatch,Чемпионат мира,ЧМ2018,TeamRussia,Команда Россия'), ('locations', '29.4980,59.7014,30.6625,60.1979')]"
# Arguments: ()

# %%
tweets = []
for line in open('fifa.json', 'r', encoding="utf8"):
    tweets.append(json.loads(line))

# %%
tonal_analysis = pd.read_csv("sentiment.csv")

# %%
list_of_tweets_en = []
list_of_tweets_es = []
list_of_tweets_fr = []
list_of_tweets_ru = []
coord_en = []
coord_es = []
coord_fr = []
coord_ru = []

def store_lang(text_lang, text_lang2, liste, list_coord, i):
    for x in range(i):
        if tweets[x].get("lang") == text_lang and text_lang2 :
            liste.append([tweets[x]["_id"],tweets[x]["text"]])
            list_coord.append(tweets[x]['geo']['coordinates'])
            
store_lang("en","uk",list_of_tweets_en,coord_en,len(tweets))
store_lang("es","es",list_of_tweets_es,coord_es,len(tweets))
store_lang("fr","fr",list_of_tweets_fr,coord_fr,len(tweets))
store_lang("ru","und",list_of_tweets_ru,coord_ru,len(tweets))

# %%
list_of_id_en = []
list_of_id_ru = []
list_of_id_fr = []
list_of_id_es = []

def preprocess_id(list_dep,list_arriv):
    for ele in list_dep:
        liste=list()
        for i in [0]:
            e=ele[i]
            e = str(e)
            e = e.split("'")
            e = e[3]
            liste.append(e)
        list_arriv.append(liste)
    for e in list_arriv:
        e = str(e)
        e = e.replace("[","")
        e = e.replace("]","")
    return list_arriv

# %%
list_of_id_en = preprocess_id(list_of_tweets_en,list_of_id_en)
list_of_id_es = preprocess_id(list_of_tweets_es,list_of_id_es)
list_of_id_fr = preprocess_id(list_of_tweets_fr,list_of_id_fr)
list_of_id_ru = preprocess_id(list_of_tweets_ru,list_of_id_ru)

# %%
list_good_id_en = []
list_good_id_ru = []
list_good_id_fr = []
list_good_id_es = []

def good_id(list_dep,list_arriv):
    for e in list_dep:
        e = str(e)
        e = e.replace("[","")
        e = e.replace("]","")
        e = e.replace("'","")
        list_arriv.append(e)
    return list_arriv

# %%
list_good_id_en = good_id(list_of_id_en,list_good_id_en)
list_good_id_ru = good_id(list_of_id_ru,list_good_id_ru)

# %%
list_all_tweets_en = []
list_all_tweets_es = []
list_all_tweets_fr = []
list_all_tweets_ru = []
for ele in list_of_tweets_en:
     list_all_tweets_en.append(ele[1])
for ele in list_of_tweets_es:
     list_all_tweets_es.append(ele[1])
for ele in list_of_tweets_fr:
     list_all_tweets_fr.append(ele[1])
for ele in list_of_tweets_ru:
     list_all_tweets_ru.append(ele[1])

# %%
list_all_tweets_en[13]
# Out:
# 'So long St. Petersburg. You were grand. Now for… https://t.co/UpfQa02MHI'

# %%
list_of_tweets_en_regex = []
list_of_tweets_es_regex = []
list_of_tweets_fr_regex = []
list_of_tweets_ru_regex = []

# %%
def transform(txt,stw):
    txt = txt.lower()
    words = word_tokenize(txt)
    filtered_sentence = []
    for w in words:
        w = ps.stem(w)
        if w not in stw:
            filtered_sentence.append(w)
    return filtered_sentence


def filtered(liste,stw):
    filtre = []
    for e in liste:
        e = e.replace("…","")
        e = re.sub(",|&|;|\.", "", e)
        e = re.sub("\'|\’|\”|\“|\—|\/", " ", e)
        e = re.sub("\"|\»|\«|\]|\[|\:|\#","", e)
        e = re.sub("\'m|\'s|\'t", "", e)
        e = re.sub("[0-9]", "", e)
        e = re.sub("\s+", " ", e)
        e = re.sub("http.*","",e)
        e = re.sub("\!|\?|\*", "", e)
        filtre.append(transform(e,stw))
    return filtre

# %%
list_of_tweets_en_regex = filtered(list_all_tweets_en,stw_en)
#list_of_tweets_ru_regex = filtered(list_all_tweets_ru,stw_ru)

# %%
list_of_tweets_en_regex
# Out:
# [['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['got',
#   'fli',
#   'russia',
#   'world',
#   'cup',
#   'hope',
#   'find',
#   'support',
#   'african',
#   'team'],
#  ['god', 'bless', 'morocco', '🇲🇦🇲🇦🇲🇦', 'footbal', 'worldcup'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['putin', 'lad', '😂🤣', 'russiaworldcup'],
#  ['first', 'game', 'world', 'cup', 'russia', '🇷🇺'],
#  ['let', 'game', 'begin', 'happi', 'world', 'cup'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['got',
#   'fli',
#   'russia',
#   'world',
#   'cup',
#   'hope',
#   'find',
#   'support',
#   'african',
#   'team'],
#  ['god', 'bless', 'morocco', '🇲🇦🇲🇦🇲🇦', 'footbal', 'worldcup'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['putin', 'lad', '😂🤣', 'russiaworldcup'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['got',
#   'fli',
#   'russia',
#   'world',
#   'cup',
#   'hope',
#   'find',
#   'support',
#   'african',
#   'team'],
#  ['god', 'bless', 'morocco', '🇲🇦🇲🇦🇲🇦', 'footbal', 'worldcup'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['got',
#   'fli',
#   'russia',
#   'world',
#   'cup',
#   'hope',
#   'find',
#   'support',
#   'african',
#   'team'],
#  ['god', 'bless', 'morocco', '🇲🇦🇲🇦🇲🇦', 'footbal', 'worldcup'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['got',
#   'fli',
#   'russia',
#   'world',
#   'cup',
#   'hope',
#   'find',
#   'support',
#   'african',
#   'team'],
#  ['god', 'bless', 'morocco', '🇲🇦🇲🇦🇲🇦', 'footbal', 'worldcup'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['got',
#   'fli',
#   'russia',
#   'world',
#   'cup',
#   'hope',
#   'find',
#   'support',
#   'african',
#   'team'],
#  ['god', 'bless', 'morocco', '🇲🇦🇲🇦🇲🇦', 'footbal', 'worldcup'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['got',
#   'fli',
#   'russia',
#   'world',
#   'cup',
#   'hope',
#   'find',
#   'support',
#   'african',
#   'team'],
#  ['god', 'bless', 'morocco', '🇲🇦🇲🇦🇲🇦', 'footbal', 'worldcup'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['putin', 'lad', '😂🤣', 'russiaworldcup'],
#  ['first', 'game', 'world', 'cup', 'russia', '🇷🇺'],
#  ['let', 'game', 'begin', 'happi', 'world', 'cup'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['stand', '@', 'saint', 'petersburg', 'russia'],
#  ['activist',
#   'kiril',
#   'kotov',
#   'wa',
#   'arrest',
#   'day',
#   'picket',
#   'world',
#   'cup'],
#  ['qajar', 'woman', 'mid-', 'averag'],
#  ['nuha', 'world', 'cup', 'russia'],
#  ['blue', 'island', 'green', 'ocean', 'skydom', 'skyabov'],
#  ['world',
#   'cup',
#   'cocain',
#   'marijuana',
#   'amp',
#   'heroin',
#   'allow',
#   'russia',
#   '(',
#   'detail',
#   ')'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['catch'],
#  ['share', 'thi', 'tbt'],
#  ['k+', 'googl', 'search', 'world', 'cup', 'schedul', 'old'],
#  ['worldcup', 'zabivaka', 'spb', '@', 'victori', 'squar'],
#  ['st', 'petersburg', 'name', 'bar'],
#  ['футбол', '@', 'europ', 'moscow'],
#  ['long', 'st', 'petersburg', 'grand'],
#  ['throwback', 'throwbackthursday', 'russia', 'sede', 'del'],
#  ['see', 'romeo', 'juliet', 'one', 'oldest'],
#  ['post', 'video', '@', 'luzhniki', 'stadium'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['present', 'wip', 'nocturn'],
#  ['-fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'fan', 'fest', 'zone', 'saint-petersburg'],
#  ['welcom', 'world', 'cup', 'russia', 'group', 'match'],
#  ['got',
#   'fli',
#   'russia',
#   'world',
#   'cup',
#   'hope',
#   'find',
#   'support',
#   'african',
#   'team'],
#  ['god', 'bless', 'morocco', '🇲🇦🇲🇦🇲🇦', 'footbal', 'worldcup'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['today', 'day👏world', 'cup', 'russia'],
#  ['putin', 'lad', '😂🤣', 'russiaworldcup'],
#  ['first', 'game', 'world', 'cup', 'russia', '🇷🇺'],
#  ['let', 'game', 'begin', 'happi', 'world', 'cup'],
#  ['world', 'cup', 'russia', 'moscow', 'costa', 'rica', '🇨🇷'],
#  ['watch',
#   'open',
#   'ceremoni',
#   'world',
#   'cup',
#   'russia',
#   'russia',
#   'vs',
#   'saudi',
#   '@',
#   'buffalowingsjo',
#   'fifaworldcup',
#   'russia',
#   'worldcup'],
#  ['let', 'kick', '⚽️', 'world', 'cup', 'russia'],
#  ['world',
#   'cup',
#   'begin',
#   'minut',
#   'start',
#   'russia',
#   'vs',
#   'saudi',
#   'arabia',
#   'god',
#   'grace',
#   'pm'],
#  ['banner',
#   'support',
#   'oleg',
#   'sentsov',
#   'near',
#   'luzhniki',
#   'stadium',
#   'today'],
#  ['🇺🇸', 'win', 'world', 'cup', 'russia'],
#  ['st', 'goal', 'worldcup', 'teamrussia', '@'],
#  ['come', 'fifafanfest', 'moscow', 'let'],
#  ['today', 'great'],
#  ['world', 'cup', 'rusia', 'russia', 'vs', 'saudi'],
#  ['post', 'photo', '@', 'fisht', 'olymp', 'stadium'],
#  ['let', 'go', 'guy', 'ru', 'worldcup', 'fifafanfest'],
#  ['world',
#   'cup',
#   'russia',
#   'ban',
#   'nigerian',
#   'support',
#   'bring',
#   'live',
#   'chicken',
#   'stadium'],
#  [],
#  ['wolv', 'riseagainst', '@', 'saint'],
#  ['@', 'chachagq', 'saint', 'petersburg', 'st-petersburg'],
#  ['enjoy', 'world', 'cup', 'russia', 'empanada', 'top'],
#  ['photo', 'taken', 'mrs_katezhna', 'arch'],
#  ['alway', 'friday', '🔥', 'vsco', 'spb', 'saintpetersburg'],
#  [],
#  ['⚽️fifa', 'world', 'cup', '⚽️', '🇷🇺', 'russia', '🇷🇺'],
#  ['proud', 'brother', 'moment', '-', 'thi', 'oldest', 'bro', '-'],
#  ['fifa', 'world', 'cup', 'russia', 'team', 'onli'],
#  ['watch', 'fifa', 'world', 'cup', 'russia', 'rest', 'denc'],
#  ['📈',
#   'fifa',
#   'world',
#   'cup',
#   'russia',
#   'group',
#   'stage',
#   'fixtur',
#   '(',
#   'npt',
#   ')'],
#  ['【🏆world', 'cup⚽️russia🇷🇺】'],
#  ['soccer', 'world', 'cup', 'russia', 'come'],
#  ['@',
#   'teamrussia',
#   'st',
#   'mention',
#   'вместемыкоманда',
#   'appear',
#   'tl',
#   'trend',
#   'topic',
#   'russia',
#   'trndnl'],
#  ['tweet',
#   'impact',
#   'вместемыкоманда',
#   'trend',
#   'wa',
#   'publish',
#   '@',
#   'teamrussia'],
#  ['verifi',
#   'account',
#   'help',
#   'turn',
#   'вместемыкоманда',
#   'trend',
#   'topic',
#   'account',
#   '@',
#   'teamrussia',
#   '@',
#   'rfpl',
#   'amp',
#   '@',
#   'jordanhalford'],
#  ['let', '‘', 'gooo🤘😎', 'wm', '❤️', 'basel', 'live\U0001f92a', 'vlog'],
#  ['remark', 'player', 'fifa', 'world', 'cup', 'russia', 'quot'],
#  ['fifa', 'world', 'cup', 'open', 'ceremoni', 'russia⚽⚽⚽⚽🏃🏃🏃🏆🏆'],
#  ['iran', 'fan', 'wait', 'tomorrow', '@', 'saint'],
#  ['@',
#   'fifaworldcup',
#   '@',
#   'teamrussia',
#   'mani',
#   'mani',
#   'congratul',
#   '💐💐',
#   '@',
#   'teamrussia',
#   '🇷🇺',
#   'worldcup',
#   'russiaworldcup',
#   '@',
#   'fifaworldcup'],
#  ['welcom', 'fifa', 'world', 'cup', 'russia', 'open', 'match', '🇷🇺⚽'],
#  ['throwback', 'bewitch', 'lure', 'russian', 'gem'],
#  ['moroccan', 'rival', 'veri', 'friendli'],
#  ['boss', 'thi', 'russia🇷🇺🇷🇺'],
#  ['world', 'cup', 'russia', 'thump', 'saudi', 'arabia', 'style'],
#  ['wa', 'amaz', 'day', 'recal', 'much', 'sunni'],
#  ['post', 'photo', '@', 'luzhniki', 'stadium'],
#  ['world', 'cup', 'russia', 'saudi', 'arabia', 'start', 'line-up'],
#  ['world', 'cup', 'russia', 'welcom', 'world'],
#  ['world', 'cup', 'russia', 'iuri', 'gazinski', 'score', 'first', 'goal'],
#  ['uniti', 'saint', 'petersburg'],
#  ['world',
#   'cup',
#   'russia',
#   'stop',
#   'nigerian',
#   'fan',
#   'bring',
#   'live',
#   'chicken',
#   'stadium'],
#  ['fifa', 'world', 'cup', 'russia', 'kick', 'llc'],
#  ['great', 'start', 'host', 'teamrussia', 'tonight'],
#  ['video', 'photo', 'first', 'day'],
#  ['amaz', '@', 'robbiewilliam', 'open', 'thi', 'month-', 'long'],
#  ['caff', 'prego'],
#  ['dog', 'play', 'guitar', ')', 'beutifulldog'],
#  ['ronaldo', '@', 'ronaldo', 'fifa'],
#  ['russia', 'today', 'world', 'cup', 'thi', 'day', 'play'],
#  ['final'],
#  ['russia', 'gazinski', 'score', 'first', 'goal', 'world', 'cup'],
#  ['beauti', 'st'],
#  ['squat', 'jump', '@', 'saint', 'petersburg', 'russia'],
#  ['one', 'one', '@', 'peter', 'paul', 'fortress'],
#  ['st', 'bean', 'saint', 'petersburg'],
#  ['phenomen', 'game', 'russia', 'go', 'ahead'],
#  ['fifa', 'world', 'cup', 'russia', 'moscow'],
#  ['sick', 'af', 'friend', 'take'],
#  ['st', 'day', 'world', 'cup', 'russia', 'done'],
#  ['world', 'cup', 'russia'],
#  ['ващенорм', '@', 'yea'],
#  ['st', 'petersburg', 'beauti', 'citi', 'rich'],
#  ['everyth', 'need', 'know', 'world', 'cup', 'russia'],
#  ['✌', 'world', 'cup', 'bluffer', 'guid', 'everi', 'team', 'russia', '-'],
#  ['ligh', 'dinner', 'st'],
#  ['nationalflagday', 'fifa', 'world', 'cup', 'russia'],
#  ['fifafanfestworldcupfootballrussiamoscow'],
#  ['world',
#   'cup',
#   '🏆🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f',
#   'спб',
#   'saintpetersburg'],
#  ['tbt', 'dont', 'care', 'post', 'thi', 'befor'],
#  ['fifa', 'world', 'cup', '-', 'russia', 'destroy', 'saudi'],
#  ['beauti', 'st', 'petersburg', 'санктпетербург', 'russia'],
#  ['fifafanfest', '@', 'fifa', 'world', 'cup', '-'],
#  ['thi', 'mean', 'thi', 'mean', '😎saintptheselittl', 'gangaremyfamili'],
#  ['thi', 'mean', 'thi', 'mean'],
#  ['𝒂𝒏𝒅', '𝒚𝒐𝒖', '𝒍𝒍', '𝒏𝒆𝒗𝒆𝒓'],
#  ['world', 'cup', 'russia', 'start', 'today'],
#  ['updat',
#   'saint',
#   'petersburg',
#   'gtf',
#   '(',
#   'st',
#   'petersburg',
#   'russia',
#   ')'],
#  ['want', 'work', 'спб', 'view', 'latest', 'open'],
#  ['world', 'cup', 'russia', '@'],
#  ['hire', 'click', 'appli', 'princip', 'sw', 'qualiti', 'eng', '-'],
#  ['hire', 'click', 'appli', 'softwar', 'engin', '-'],
#  ['interest', 'job', 'спб', 'thi', 'could', 'great', 'fit'],
#  ['let', 'go', 'win', 'world', 'cup', 'fifa', 'russia'],
#  ['want', 'work', 'dell', 'hire', 'спб', 'click', 'detail'],
#  ['look', 'work', 'спб', 'check', 'thi', 'job'],
#  ['look', 'work', 'спб', 'check', 'thi', 'job'],
#  ['throwback', 'stpetersburg', 'mosqu', '🕌russia'],
#  ['urban', 'inner', 'space', 'downtownstrol', 'gate'],
#  ['vscocam', 'spb', 'sneaker', 'offwhit', 'bw', '@', 'babochka'],
#  ['mellow', 'lonesom'],
#  ['🚶🏻\u200d♀️🍃☀️', '@', 'saint'],
#  ['thi',
#   'job',
#   'might',
#   'great',
#   'fit',
#   'senior',
#   'softwar',
#   'qualiti',
#   'engin',
#   '-'],
#  ['join', 'dell', 'team', 'see', 'latest', 'job', 'open'],
#  ['saint', 'petersburg', '-', '@', 'gov_spb', 'st-petersburg'],
#  ['push-up', '💪', '@', 'saint', 'petersburg', 'russia'],
#  ['push', 'ups🙄', '@', 'saint', 'petersburg', 'russia'],
#  ['rt',
#   'world',
#   'cup',
#   'russia',
#   'real',
#   'time',
#   'ground',
#   'footag',
#   '-',
#   'day',
#   '(',
#   'tape',
#   ')'],
#  ['hire', 'click', 'appli', 'senior', 'softwar', 'qualiti', 'engin', '-'],
#  ['jess',
#   'elli',
#   'lingard',
#   '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f',
#   'russia',
#   'vsco'],
#  ['look', 'work', 'спб', 'check', 'thi', 'job'],
#  ['thi', 'morn', 'miler', 'park', 'imeni'],
#  ['octopus', 'garden'],
#  ['recommend',
#   'anyon',
#   'thi',
#   'job',
#   'senior',
#   'softwar',
#   'qualiti',
#   'engin',
#   '-'],
#  ['finish', 'run', 'km', 'ms', 'endomondo', 'endorphin'],
#  ['wa', 'veri', 'nice', 'event', 'famou'],
#  ['fifa', 'world', 'cup', '📍russia', 'travel', 'wanderlust'],
#  ['fifa', 'world', 'cup', '📍russia', 'travel', 'wanderlust'],
#  ['vision', 'futur', 'artobject', 'artmuza_spb'],
#  ['luzhniki', 'stadium', 'moscow', 'play'],
#  ['post', 'photo'],
#  ['match', 'fifa', 'world', 'cup', 'russia'],
#  ['fifa', 'world', 'cup', 'russia', 'russia'],
#  ['fifa', 'world', 'cup', 'start', 'let'],
#  ['lift', 'sky', 'undersid', 'photo'],
#  ['readi', 'rock', 'riseagainst', '@', 'а', 'green'],
#  ['result', 'want', 'way'],
#  ['tmmr', 'product', 'offic'],
#  ['saint', 'petersburg', 'sun', 'goe'],
#  ['intern', 'special', 'build'],
#  ['lift', 'sky', 'deadwal', 'saintpetersburg'],
#  ['keep', 'quiet', 'longer', 'sing'],
#  ['nike', 'refus', 'give', 'player', 'cleat', 'adida'],
#  ['desd', 'sochi', 'con', '❤️', 'en', 'fisht', 'olymp', 'stadium'],
#  ['stori', 'md', 'intellectualmassag', 'ph'],
#  ['gang', 'da', 'hood', '🔴⚓️⚫️', 'primaonelov', 'footbal'],
#  ['¡vamo', '@', 'fifa', 'world', 'cup', 'russia'],
#  ['teammat', 'becom', 'rival', 'futbol', 'frenzi'],
#  ['may', 'heaven', 'befor', 'devil', 'know'],
#  ['sport', 'techi', 'hq', 'fifa', 'world', 'cup', 'russia'],
#  ['dream', 'unlik', 'long'],
#  ['hello',
#   'world',
#   'hello',
#   'onli',
#   'one',
#   'song',
#   'repeat',
#   'today',
#   '-',
#   'new',
#   'one',
#   'imaginedragon',
#   '❤️',
#   '(',
#   '@',
#   'лахт'],
#  ['alreadi', 'part', 'muaythai', '@', 'saint'],
#  ['show', 'mine', 'show'],
#  ['feel', 'heat', 'hold'],
#  ['best', 'team', 'festiv', 'life', '❤️❤️❤️', 'guy'],
#  ['iranian', 'soccer', 'nation', 'team', '-', 'one', 'team', 'one'],
#  ['wth', '🇮🇷', '😳😳😳😳😳😉😉😉', 'gq', 'gqmodel'],
#  ['time💪🏽🇮🇷💪🏽'],
#  ['stori', 'md', 'intellectualmassag', 'ph'],
#  ['world', 'cup', 'russia', 'go', 'nippon'],
#  ['two', 'think'],
#  ['person', 'worldcup', '🏆', 'fifafanfest'],
#  ['go', 'morocco'],
#  ['welcom', 'world', 'cup', 'moscowrussia'],
#  ['awhil', 'sinc', 'seen', 'name'],
#  ['line', 'morroco', 'vs', 'iran', 'worldcup'],
#  ['see', 'storm', 'eye', 'fall'],
#  ['metro', 'morocco', 'fan', '@', 'stade', 'de'],
#  ['@', 'fifawwc', '@', 'fisht', 'olymp', 'stadium'],
#  ['let', 'get', 'boy', '🇮🇷🇮🇷🇮🇷🇮🇷🇮🇷🇮🇷🇮🇷', '@', 'zenit', 'arena'],
#  ['stori', 'md', 'intellectualmassag', 'ph'],
#  ['lunch', 'time', '🍣', 'gustogram', 'saint', 'petersburg'],
#  ['repost', '@', 'riseagainst', 'spb', '💜', '@', 'saint'],
#  ['post', 'photo', '@', 'church', 'savior'],
#  ['photo', 'booth', '📸', 'say', 'chees', '\U0001f92a', 'galeria', 'mall'],
#  ['drink',
#   'stone',
#   'xocoveza',
#   '@',
#   'stonebrew',
#   '@',
#   'insurgentebrew',
#   '@',
#   'blinder'],
#  ['finish', 'run', 'km', 'ms', 'endomondo', 'endorphin'],
#  ['world',
#   'cup',
#   'ghana',
#   'coach',
#   'stephen',
#   'appiah',
#   'reveal',
#   'african',
#   'countri',
#   'well',
#   'russia'],
#  ['sexi', 'lexi'],
#  ['morocco', 'vs', 'ir', 'iran', 'duel', 'two', 'black'],
#  ['morocco', 'vs', 'ir', 'iran', 'duel', 'two', 'black'],
#  ['fifa', 'world', 'cup', 'russia'],
#  ['staret', 'fifaworldcup'],
#  ['world', 'cup', 'russia', 'group', 'match', 'day'],
#  ['let', 'laugh', 'dive', '@', 'socceram', 'worldcup'],
#  ['goal', 'yet', 'russiaworldcup'],
#  ['blue', 'sky', 'sunni', 'day', 'downtown', 'sky'],
#  ['one', 'time', 'ромеоиджульеттаавербуха', '@'],
#  ['post', 'video', '@', 'zenit', 'arena', 'st', 'petersburg'],
#  ['stadium', '@', 'saint', 'petersburg', 'russia'],
#  ['hardli', 'home', 'alway', 'rep', '@', 'zenit', 'arena', 'st'],
#  ['finish', 'cycl', 'km', 'hm', 'endomondo', 'endorphin'],
#  ['look', 'deeper', 'anyon', 'ever', 'ha'],
#  ['late', 'goal', '@', 'saint', 'petersburg', 'russia'],
#  ['crave', 'deep', 'understand', 'born', 'outsid'],
#  ['adida', '®', 'footbal'],
#  ['late', 'goal', 'stop', 'iran', 'un', 'win'],
#  ['nation', 'heartbeat', 'iran', '@', 'zenit', 'arena', 'st'],
#  ['nation', 'heartbeat', 'iran', '@', 'zenit', 'arena', 'st'],
#  ['th', 'minut', 'goal', 'give', 'iran', 'second'],
#  ['portug', 'spain', 'poresp', '@', 'fisht', 'olymp', 'stadium'],
#  ['prost',
#   'poresp',
#   '🇵🇹',
#   '🇪🇸',
#   'wm',
#   'worldcup',
#   'fernprost',
#   '🍻',
#   'beertweet',
#   '-',
#   'drink',
#   'sagr',
#   'branca',
#   '@',
#   'cervejasagr',
#   '@'],
#  ['finish', 'cycl', 'km', 'hm', 'endomondo', 'endorphin'],
#  ['wm', 'fulli'],
#  ['fan', 'iran', 'sportphotographi'],
#  ['🇵🇹',
#   '⚽️',
#   '🇪🇸',
#   'worldcup',
#   'porspa',
#   '(',
#   '@',
#   'grizzli',
#   'bar',
#   'saint',
#   'petersburg',
#   'st-petersburg',
#   ')'],
#  ['jess',
#   'elli',
#   'lingard',
#   '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f',
#   'russia',
#   'vsco'],
#  ['tweet',
#   'impact',
#   'португалияиспания',
#   'trend',
#   'wa',
#   'publish',
#   '@',
#   'sportsru'],
#  ['worldcup',
#   '-',
#   'dimamaghreb',
#   'morocco',
#   'vs',
#   'allforteammelli',
#   'iran',
#   'goal',
#   'bouhaddouz',
#   '(',
#   'goal',
#   ')'],
#  ['peitch', 'da', '(', 'dont'],
#  ['night', 'rememb', 'mobarak', 'iran', 'bachehaa'],
#  ['@', 'chachagq', 'saint', 'petersburg', 'st-petersburg'],
#  ['shade', 'saintpetersburg', 'randomphoto', '@'],
#  ['shade', 'saintpetersburg', '@', 'saint', 'petersburg'],
#  ['everybodi', 'heard', 'bird', 'vscocam', 'spb'],
#  ['church', 'savior'],
#  ['post', 'photo'],
#  ['post', 'photo'],
#  ['мокро', '@', 'yea', 'park'],
#  ['arni', 'club', 'saint', 'petersburg', 'st-petersburg'],
#  ['🇻🇳', '🇮🇷', '@', 'saint'],
#  ['portug', '-', 'spain', '@', 'fisht', 'olymp', 'stadium'],
#  ['good', 'day', 'give', 'happi', 'bad', 'day', 'give'],
#  ['world',
#   'cup',
#   'saudi',
#   'arabia',
#   'fa',
#   'vow',
#   'punish',
#   'player',
#   '-',
#   'defeat',
#   'russia'],
#  ['walk'],
#  ...]

# %%
def list_join(liste):
    list_final = []
    i = 0
    while i < len(liste):
        list_final.append(' '.join(liste[i]))
        i=i+1
    return list_final

# %%
list_low_en = list_join(list_of_tweets_en_regex)
list_low_ru = list_join(list_of_tweets_ru_regex)

# %%
dict_en = dict(zip(list_good_id_en, list_low_en))
dict_es = dict(zip(list_good_id_es, list_low_es))
dict_fr = dict(zip(list_good_id_fr, list_low_fr))
dict_ru = dict(zip(list_good_id_ru, list_low_ru))

# %%
dict_en
# Out:
# {'5b30dddaa8059696856d2cc1': 'stand @ saint petersburg russia',
#  '5b30dddaa8059696856d2d9b': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30dddaa8059696856d2f66': 'qajar woman mid- average…',
#  '5b30dddca8059696856d407c': 'nuha world cup russia',
#  '5b30dddca8059696856d42cc': 'blue island green ocean skydom skyabove…',
#  '5b30dddda8059696856d4a49': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30dddda8059696856d4ada': 'world cup russia welcom world',
#  '5b30dddea8059696856d4c8c': 'catch my…',
#  '5b30dddea8059696856d513d': 'share thi tbt in…',
#  '5b30dddfa8059696856d52ff': 'k+ googl search world cup schedul old',
#  '5b30dddfa8059696856d5373': 'worldcup zabivaka spb @ victori square…',
#  '5b30dddfa8059696856d5763': 'st petersburg name bar the…',
#  '5b30dde0a8059696856d5db0': 'футбол @ europ moscow',
#  '5b30dde1a8059696856d6267': 'long st petersburg grand for…',
#  '5b30dde1a8059696856d64d8': 'throwback throwbackthursday russia sede del…',
#  '5b30dde1a8059696856d6946': 'see romeo juliet one oldest…',
#  '5b30dde2a8059696856d6c49': 'post video @ luzhniki stadium',
#  '5b30dde2a8059696856d712b': 'fifa world cup russia',
#  '5b30dde3a8059696856d76e6': 'post photo @ luzhniki stadium',
#  '5b30dde5a8059696856d8434': 'present wip nocturne…',
#  '5b30e3c8dbf70ad71b268092': 'stand @ saint petersburg russia',
#  '5b30e3c8dbf70ad71b26816c': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30e3c8dbf70ad71b268337': 'qajar woman mid- average…',
#  '5b30e3df81f81adef24250d5': 'stand @ saint petersburg russia',
#  '5b30e3df81f81adef24251af': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30e3df81f81adef242537a': 'qajar woman mid- average…',
#  '5b30e3e181f81adef2426490': 'nuha world cup russia',
#  '5b30e3e181f81adef24266e0': 'blue island green ocean skydom skyabove…',
#  '5b30e3e281f81adef2426e5d': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30e3e281f81adef2426eee': 'world cup russia welcom world',
#  '5b30e3e381f81adef24270a0': 'catch my…',
#  '5b30e3e381f81adef2427551': 'share thi tbt in…',
#  '5b30e3e481f81adef2427713': 'k+ googl search world cup schedul old',
#  '5b30e3e481f81adef2427787': 'worldcup zabivaka spb @ victori square…',
#  '5b30e3e481f81adef2427b77': 'st petersburg name bar the…',
#  '5b30e3e581f81adef24281c4': 'футбол @ europ moscow',
#  '5b30e3e581f81adef242867b': 'long st petersburg grand for…',
#  '5b30e3e581f81adef24288ec': 'throwback throwbackthursday russia sede del…',
#  '5b30e3e681f81adef2428d5a': 'see romeo juliet one oldest…',
#  '5b30e3e681f81adef242905d': 'post video @ luzhniki stadium',
#  '5b30e3e781f81adef242953f': 'fifa world cup russia',
#  '5b30e3e881f81adef2429afa': 'post photo @ luzhniki stadium',
#  '5b30e4bca076c81194cb4827': 'stand @ saint petersburg russia',
#  '5b30e4bca076c81194cb4901': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30e4bca076c81194cb4acc': 'qajar woman mid- average…',
#  '5b30e4bfa076c81194cb5be2': 'nuha world cup russia',
#  '5b30e4bfa076c81194cb5e32': 'blue island green ocean skydom skyabove…',
#  '5b30ecacdeff1914f84963f1': 'stand @ saint petersburg russia',
#  '5b30ecacdeff1914f84964cb': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30ecacdeff1914f8496696': 'qajar woman mid- average…',
#  '5b30ecafdeff1914f84977ac': 'nuha world cup russia',
#  '5b30ecafdeff1914f84979fc': 'blue island green ocean skydom skyabove…',
#  '5b30ecb0deff1914f8498179': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30ecb0deff1914f849820a': 'world cup russia welcom world',
#  '5b30ecb0deff1914f84983bc': 'catch my…',
#  '5b30ecb1deff1914f849886d': 'share thi tbt in…',
#  '5b30ecb1deff1914f8498a2f': 'k+ googl search world cup schedul old',
#  '5b30ecb1deff1914f8498aa3': 'worldcup zabivaka spb @ victori square…',
#  '5b30ecb2deff1914f8498e93': 'st petersburg name bar the…',
#  '5b30ecb2deff1914f84994e0': 'футбол @ europ moscow',
#  '5b30ecb3deff1914f8499997': 'long st petersburg grand for…',
#  '5b30ecb3deff1914f8499c08': 'throwback throwbackthursday russia sede del…',
#  '5b30ecb4deff1914f849a076': 'see romeo juliet one oldest…',
#  '5b30ecb4deff1914f849a379': 'post video @ luzhniki stadium',
#  '5b30ecb5deff1914f849a85b': 'fifa world cup russia',
#  '5b30ecb6deff1914f849ae16': 'post photo @ luzhniki stadium',
#  '5b30ecb8deff1914f849bb64': 'present wip nocturne…',
#  '5b30f08b5970d8fd15e7d978': 'stand @ saint petersburg russia',
#  '5b30f08c5970d8fd15e7da52': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f08c5970d8fd15e7dc1d': 'qajar woman mid- average…',
#  '5b30f08e5970d8fd15e7ed33': 'nuha world cup russia',
#  '5b30f08f5970d8fd15e7ef83': 'blue island green ocean skydom skyabove…',
#  '5b30f0905970d8fd15e7f700': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f0905970d8fd15e7f791': 'world cup russia welcom world',
#  '5b30f0905970d8fd15e7f943': 'catch my…',
#  '5b30f0915970d8fd15e7fdf4': 'share thi tbt in…',
#  '5b30f0915970d8fd15e7ffb6': 'k+ googl search world cup schedul old',
#  '5b30f0915970d8fd15e8002a': 'worldcup zabivaka spb @ victori square…',
#  '5b30f0925970d8fd15e8041a': 'st petersburg name bar the…',
#  '5b30f0935970d8fd15e80a67': 'футбол @ europ moscow',
#  '5b30f0945970d8fd15e80f1e': 'long st petersburg grand for…',
#  '5b30f0945970d8fd15e8118f': 'throwback throwbackthursday russia sede del…',
#  '5b30f0955970d8fd15e815fd': 'see romeo juliet one oldest…',
#  '5b30f0955970d8fd15e81900': 'post video @ luzhniki stadium',
#  '5b30f0965970d8fd15e81de2': 'fifa world cup russia',
#  '5b30f0975970d8fd15e8239d': 'post photo @ luzhniki stadium',
#  '5b30f0995970d8fd15e830eb': 'present wip nocturne…',
#  '5b30f09c5970d8fd15e83ff7': '-fifa world cup russia …',
#  '5b30f09f5970d8fd15e84fa7': 'fifa fan fest zone saint-petersburg',
#  '5b30f09f5970d8fd15e851e7': 'welcom world cup russia group match…',
#  '5b30f09f5970d8fd15e85568': 'got fli russia world cup hope find support african team',
#  '5b30f0a05970d8fd15e85819': 'god bless morocco : morocco : :morocco : :morocco : footbal worldcup…',
#  '5b30f0a15970d8fd15e85f3f': 'today day : clapping_hand : world cup russia our…',
#  '5b30f0a35970d8fd15e8705d': 'today day : clapping_hand : world cup russia our…',
#  '5b30f0a45970d8fd15e87bc6': 'putin lad : face_with_tears_of_joy : :rolling_on_the_floor_laugh : russiaworldcup',
#  '5b30f0a55970d8fd15e88335': 'first game world cup russia : russia : and…',
#  '5b30f0a65970d8fd15e886a1': 'let game begin happi world cup…',
#  '5b30f190ffb5041f0dada590': 'stand @ saint petersburg russia',
#  '5b30f190ffb5041f0dada66a': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f191ffb5041f0dada835': 'qajar woman mid- average…',
#  '5b30f1aa1f31bddaea300fd3': 'stand @ saint petersburg russia',
#  '5b30f1aa1f31bddaea3010ad': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f1aa1f31bddaea301278': 'qajar woman mid- average…',
#  '5b30f1ad1f31bddaea30238e': 'nuha world cup russia',
#  '5b30f1ad1f31bddaea3025de': 'blue island green ocean skydom skyabove…',
#  '5b30f1ae1f31bddaea302d5b': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f1ae1f31bddaea302dec': 'world cup russia welcom world',
#  '5b30f1af1f31bddaea302f9e': 'catch my…',
#  '5b30f1af1f31bddaea30344f': 'share thi tbt in…',
#  '5b30f1b01f31bddaea303611': 'k+ googl search world cup schedul old',
#  '5b30f1b01f31bddaea303685': 'worldcup zabivaka spb @ victori square…',
#  '5b30f1b01f31bddaea303a75': 'st petersburg name bar the…',
#  '5b30f1b11f31bddaea3040c2': 'футбол @ europ moscow',
#  '5b30f1b21f31bddaea304579': 'long st petersburg grand for…',
#  '5b30f1b21f31bddaea3047ea': 'throwback throwbackthursday russia sede del…',
#  '5b30f1b31f31bddaea304c58': 'see romeo juliet one oldest…',
#  '5b30f1b41f31bddaea304f5b': 'post video @ luzhniki stadium',
#  '5b30f1b51f31bddaea30543d': 'fifa world cup russia',
#  '5b30f1b61f31bddaea3059f8': 'post photo @ luzhniki stadium',
#  '5b30f1b81f31bddaea306746': 'present wip nocturne…',
#  '5b30f1ba1f31bddaea307652': '-fifa world cup russia …',
#  '5b30f1bc1f31bddaea308602': 'fifa fan fest zone saint-petersburg',
#  '5b30f1bd1f31bddaea308842': 'welcom world cup russia group match…',
#  '5b30f1bd1f31bddaea308bc3': 'got fli russia world cup hope find support african team',
#  '5b30f1be1f31bddaea308e74': 'god bless morocco : morocco : :morocco : :morocco : footbal worldcup…',
#  '5b30f1be1f31bddaea30959a': 'today day : clapping_hand : world cup russia our…',
#  '5b30f1c11f31bddaea30a6b8': 'today day : clapping_hand : world cup russia our…',
#  '5b30f1c21f31bddaea30b221': 'putin lad : face_with_tears_of_joy : :rolling_on_the_floor_laugh : russiaworldcup',
#  '5b30f26e57e4a5ca787e8166': 'stand @ saint petersburg russia',
#  '5b30f26e57e4a5ca787e823c': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f26f57e4a5ca787e8407': 'qajar woman mid- average…',
#  '5b30f27157e4a5ca787e951f': 'nuha world cup russia',
#  '5b30f29d01d837831c62b806': 'stand @ saint petersburg russia',
#  '5b30f29d01d837831c62b8e0': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f29d01d837831c62baab': 'qajar woman mid- average…',
#  '5b30f29f01d837831c62cbc1': 'nuha world cup russia',
#  '5b30f2a001d837831c62ce11': 'blue island green ocean skydom skyabove…',
#  '5b30f2a101d837831c62d58e': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f2a101d837831c62d61f': 'world cup russia welcom world',
#  '5b30f2a101d837831c62d7d1': 'catch my…',
#  '5b30f2a201d837831c62dc82': 'share thi tbt in…',
#  '5b30f2a201d837831c62de44': 'k+ googl search world cup schedul old',
#  '5b30f2a201d837831c62deb8': 'worldcup zabivaka spb @ victori square…',
#  '5b30f2a301d837831c62e2a8': 'st petersburg name bar the…',
#  '5b30f2a401d837831c62e8f5': 'футбол @ europ moscow',
#  '5b30f2a501d837831c62edac': 'long st petersburg grand for…',
#  '5b30f2a501d837831c62f01d': 'throwback throwbackthursday russia sede del…',
#  '5b30f2a601d837831c62f48b': 'see romeo juliet one oldest…',
#  '5b30f2a701d837831c62f78e': 'post video @ luzhniki stadium',
#  '5b30f2a701d837831c62fc70': 'fifa world cup russia',
#  '5b30f2a801d837831c63022b': 'post photo @ luzhniki stadium',
#  '5b30f2ab01d837831c630f79': 'present wip nocturne…',
#  '5b30f2ad01d837831c631e85': '-fifa world cup russia …',
#  '5b30f2af01d837831c632e35': 'fifa fan fest zone saint-petersburg',
#  '5b30f2b001d837831c633075': 'welcom world cup russia group match…',
#  '5b30f2b001d837831c6333f6': 'got fli russia world cup hope find support african team',
#  '5b30f2b101d837831c6336a7': 'god bless morocco : morocco : :morocco : :morocco : footbal worldcup…',
#  '5b30f2b101d837831c633dcd': 'today day : clapping_hand : world cup russia our…',
#  '5b30f2b301d837831c634eeb': 'today day : clapping_hand : world cup russia our…',
#  '5b30f2ca2658cc5a97e4a58e': 'stand @ saint petersburg russia',
#  '5b30f2ca2658cc5a97e4a668': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f2cb2658cc5a97e4a833': 'qajar woman mid- average…',
#  '5b30f2cd2658cc5a97e4b949': 'nuha world cup russia',
#  '5b30f2ce2658cc5a97e4bb99': 'blue island green ocean skydom skyabove…',
#  '5b30f2dd6823b1fcf1865d42': 'stand @ saint petersburg russia',
#  '5b30f2dd6823b1fcf1865e1c': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f2dd6823b1fcf1865fe7': 'qajar woman mid- average…',
#  '5b30f2e06823b1fcf18670fd': 'nuha world cup russia',
#  '5b30f2e06823b1fcf186734d': 'blue island green ocean skydom skyabove…',
#  '5b30f2e16823b1fcf1867aca': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f2e16823b1fcf1867b5b': 'world cup russia welcom world',
#  '5b30f2e26823b1fcf1867d0d': 'catch my…',
#  '5b30f2e36823b1fcf18681be': 'share thi tbt in…',
#  '5b30f2e36823b1fcf1868380': 'k+ googl search world cup schedul old',
#  '5b30f2e36823b1fcf18683f4': 'worldcup zabivaka spb @ victori square…',
#  '5b30f2e46823b1fcf18687e4': 'st petersburg name bar the…',
#  '5b30f2e56823b1fcf1868e31': 'футбол @ europ moscow',
#  '5b30f2e56823b1fcf18692e8': 'long st petersburg grand for…',
#  '5b30f2e66823b1fcf1869559': 'throwback throwbackthursday russia sede del…',
#  '5b30f2e76823b1fcf18699c7': 'see romeo juliet one oldest…',
#  '5b30f2e76823b1fcf1869cca': 'post video @ luzhniki stadium',
#  '5b30f2e86823b1fcf186a1ac': 'fifa world cup russia',
#  '5b30f2e96823b1fcf186a767': 'post photo @ luzhniki stadium',
#  '5b30f2f46823b1fcf186b4b5': 'present wip nocturne…',
#  '5b30f3006823b1fcf186c3c1': '-fifa world cup russia …',
#  '5b30f30d6823b1fcf186d371': 'fifa fan fest zone saint-petersburg',
#  '5b30f30f6823b1fcf186d5b1': 'welcom world cup russia group match…',
#  '5b30f3116823b1fcf186d932': 'got fli russia world cup hope find support african team',
#  '5b30f3136823b1fcf186dbe3': 'god bless morocco : morocco : :morocco : :morocco : footbal worldcup…',
#  '5b30f3176823b1fcf186e309': 'today day : clapping_hand : world cup russia our…',
#  '5b30f3ae22198c8439eadc71': 'stand @ saint petersburg russia',
#  '5b30f3af22198c8439eadd4b': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f3af22198c8439eadf16': 'qajar woman mid- average…',
#  '5b30f3b222198c8439eaf02c': 'nuha world cup russia',
#  '5b30f3b222198c8439eaf27c': 'blue island green ocean skydom skyabove…',
#  '5b30f3b422198c8439eaf9f9': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f3b422198c8439eafa8a': 'world cup russia welcom world',
#  '5b30f3c3d85e36841fb6a441': 'stand @ saint petersburg russia',
#  '5b30f3c3d85e36841fb6a51b': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f3c4d85e36841fb6a6e6': 'qajar woman mid- average…',
#  '5b30f3c6d85e36841fb6b7fc': 'nuha world cup russia',
#  '5b30f3c7d85e36841fb6ba4c': 'blue island green ocean skydom skyabove…',
#  '5b30f3c8d85e36841fb6c1c9': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f3c8d85e36841fb6c25a': 'world cup russia welcom world',
#  '5b30f3c8d85e36841fb6c40c': 'catch my…',
#  '5b30f3c9d85e36841fb6c8bd': 'share thi tbt in…',
#  '5b30f3c9d85e36841fb6ca7f': 'k+ googl search world cup schedul old',
#  '5b30f3c9d85e36841fb6caf3': 'worldcup zabivaka spb @ victori square…',
#  '5b30f3cad85e36841fb6cee3': 'st petersburg name bar the…',
#  '5b30f3cbd85e36841fb6d530': 'футбол @ europ moscow',
#  '5b30f3ccd85e36841fb6d9e7': 'long st petersburg grand for…',
#  '5b30f3ccd85e36841fb6dc58': 'throwback throwbackthursday russia sede del…',
#  '5b30f3cdd85e36841fb6e0c6': 'see romeo juliet one oldest…',
#  '5b30f3cdd85e36841fb6e3c9': 'post video @ luzhniki stadium',
#  '5b30f3ced85e36841fb6e8ab': 'fifa world cup russia',
#  '5b30f3cfd85e36841fb6ee66': 'post photo @ luzhniki stadium',
#  '5b30f3d1d85e36841fb6fbb4': 'present wip nocturne…',
#  '5b30f3d4d85e36841fb70ac0': '-fifa world cup russia …',
#  '5b30f3d7d85e36841fb71a70': 'fifa fan fest zone saint-petersburg',
#  '5b30f3d7d85e36841fb71cb0': 'welcom world cup russia group match…',
#  '5b30f3d7d85e36841fb72031': 'got fli russia world cup hope find support african team',
#  '5b30f3d8d85e36841fb722e2': 'god bless morocco : morocco : :morocco : :morocco : footbal worldcup…',
#  '5b30f3d9d85e36841fb72a08': 'today day : clapping_hand : world cup russia our…',
#  '5b30f4883862643d0c2a6799': 'stand @ saint petersburg russia',
#  '5b30f4883862643d0c2a6873': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f4883862643d0c2a6a3e': 'qajar woman mid- average…',
#  '5b30f48b3862643d0c2a7b54': 'nuha world cup russia',
#  '5b30f48c3862643d0c2a7da4': 'blue island green ocean skydom skyabove…',
#  '5b30f48d3862643d0c2a8521': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f48d3862643d0c2a85b2': 'world cup russia welcom world',
#  '5b30f539ae7749446e440f4a': 'stand @ saint petersburg russia',
#  '5b30f539ae7749446e441024': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f539ae7749446e4411ef': 'qajar woman mid- average…',
#  '5b30f53cae7749446e442305': 'nuha world cup russia',
#  '5b30f53cae7749446e442555': 'blue island green ocean skydom skyabove…',
#  '5b30f53dae7749446e442cd2': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f53dae7749446e442d63': 'world cup russia welcom world',
#  '5b30f53eae7749446e442f15': 'catch my…',
#  '5b30f53eae7749446e4433c6': 'share thi tbt in…',
#  '5b30f53fae7749446e443588': 'k+ googl search world cup schedul old',
#  '5b30f53fae7749446e4435fc': 'worldcup zabivaka spb @ victori square…',
#  '5b30f540ae7749446e4439ec': 'st petersburg name bar the…',
#  '5b30f540ae7749446e444039': 'футбол @ europ moscow',
#  '5b30f541ae7749446e4444f0': 'long st petersburg grand for…',
#  '5b30f542ae7749446e444761': 'throwback throwbackthursday russia sede del…',
#  '5b30f542ae7749446e444bcf': 'see romeo juliet one oldest…',
#  '5b30f543ae7749446e444ed2': 'post video @ luzhniki stadium',
#  '5b30f543ae7749446e4453b4': 'fifa world cup russia',
#  '5b30f544ae7749446e44596f': 'post photo @ luzhniki stadium',
#  '5b30f547ae7749446e4466bd': 'present wip nocturne…',
#  '5b30f549ae7749446e4475c9': '-fifa world cup russia …',
#  '5b30f54cae7749446e448579': 'fifa fan fest zone saint-petersburg',
#  '5b30f54cae7749446e4487b9': 'welcom world cup russia group match…',
#  '5b30f54cae7749446e448b3a': 'got fli russia world cup hope find support african team',
#  '5b30f54dae7749446e448deb': 'god bless morocco : morocco : :morocco : :morocco : footbal worldcup…',
#  '5b30f54eae7749446e449511': 'today day : clapping_hand : world cup russia our…',
#  '5b30f605181ba16e66a341cb': 'stand @ saint petersburg russia',
#  '5b30f605181ba16e66a342a5': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f605181ba16e66a34470': 'qajar woman mid- average…',
#  '5b30f609181ba16e66a35586': 'nuha world cup russia',
#  '5b30f609181ba16e66a357d6': 'blue island green ocean skydom skyabove…',
#  '5b30f60a181ba16e66a35f53': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f60a181ba16e66a35fe4': 'world cup russia welcom world',
#  '5b30f60b181ba16e66a36196': 'catch my…',
#  '5b30f65162b85ac4769eb116': 'stand @ saint petersburg russia',
#  '5b30f65162b85ac4769eb1f0': 'activist kiril kotov wa arrest day picket world cup',
#  '5b30f65162b85ac4769eb3bb': 'qajar woman mid- average…',
#  '5b30f65462b85ac4769ec4d1': 'nuha world cup russia',
#  '5b30f65462b85ac4769ec721': 'blue island green ocean skydom skyabove…',
#  '5b30f65562b85ac4769ece9e': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b30f65562b85ac4769ecf2f': 'world cup russia welcom world',
#  '5b30f65662b85ac4769ed0e1': 'catch my…',
#  '5b30f65762b85ac4769ed592': 'share thi tbt in…',
#  '5b30f65762b85ac4769ed754': 'k+ googl search world cup schedul old',
#  '5b30f65762b85ac4769ed7c8': 'worldcup zabivaka spb @ victori square…',
#  '5b30f65862b85ac4769edbb8': 'st petersburg name bar the…',
#  '5b30f65962b85ac4769ee205': 'футбол @ europ moscow',
#  '5b30f65962b85ac4769ee6bc': 'long st petersburg grand for…',
#  '5b30f65a62b85ac4769ee92d': 'throwback throwbackthursday russia sede del…',
#  '5b30f65a62b85ac4769eed9b': 'see romeo juliet one oldest…',
#  '5b30f65b62b85ac4769ef09e': 'post video @ luzhniki stadium',
#  '5b30f65c62b85ac4769ef580': 'fifa world cup russia',
#  '5b30f65d62b85ac4769efb3b': 'post photo @ luzhniki stadium',
#  '5b30f65f62b85ac4769f0889': 'present wip nocturne…',
#  '5b30f66262b85ac4769f1795': '-fifa world cup russia …',
#  '5b30f66462b85ac4769f2745': 'fifa fan fest zone saint-petersburg',
#  '5b30f66562b85ac4769f2985': 'welcom world cup russia group match…',
#  '5b338c26422477dfab8e6f0e': 'stand @ saint petersburg russia',
#  '5b338c27422477dfab8e6fe8': 'activist kiril kotov wa arrest day picket world cup',
#  '5b338c27422477dfab8e71b3': 'qajar woman mid- average…',
#  '5b338c29422477dfab8e82c9': 'nuha world cup russia',
#  '5b338c2a422477dfab8e8519': 'blue island green ocean skydom skyabove…',
#  '5b338c2b422477dfab8e8c96': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b338c2b422477dfab8e8d27': 'world cup russia welcom world',
#  '5b338c2b422477dfab8e8ed9': 'catch my…',
#  '5b338c2c422477dfab8e938a': 'share thi tbt in…',
#  '5b338c2c422477dfab8e954c': 'k+ googl search world cup schedul old',
#  '5b338c2c422477dfab8e95c0': 'worldcup zabivaka spb @ victori square…',
#  '5b338c2d422477dfab8e99b0': 'st petersburg name bar the…',
#  '5b338c2e422477dfab8e9ffd': 'футбол @ europ moscow',
#  '5b338c2e422477dfab8ea4b4': 'long st petersburg grand for…',
#  '5b338c2f422477dfab8ea725': 'throwback throwbackthursday russia sede del…',
#  '5b338c2f422477dfab8eab93': 'see romeo juliet one oldest…',
#  '5b338c30422477dfab8eae96': 'post video @ luzhniki stadium',
#  '5b338c31422477dfab8eb378': 'fifa world cup russia',
#  '5b338c32422477dfab8eb933': 'post photo @ luzhniki stadium',
#  '5b338c34422477dfab8ec681': 'present wip nocturne…',
#  '5b338c37422477dfab8ed58d': '-fifa world cup russia …',
#  '5b338c39422477dfab8ee53d': 'fifa fan fest zone saint-petersburg',
#  '5b338c39422477dfab8ee77d': 'welcom world cup russia group match…',
#  '5b338ceaa5d973963e1701b1': 'stand @ saint petersburg russia',
#  '5b338ceaa5d973963e17028b': 'activist kiril kotov wa arrest day picket world cup',
#  '5b338ceba5d973963e170456': 'qajar woman mid- average…',
#  '5b338ceda5d973963e17156c': 'nuha world cup russia',
#  '5b338ceda5d973963e1717bc': 'blue island green ocean skydom skyabove…',
#  '5b338ceea5d973963e171f39': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b338ceea5d973963e171fca': 'world cup russia welcom world',
#  '5b338cefa5d973963e17217c': 'catch my…',
#  '5b338cf0a5d973963e17262d': 'share thi tbt in…',
#  '5b338cf0a5d973963e1727ef': 'k+ googl search world cup schedul old',
#  '5b338cf0a5d973963e172863': 'worldcup zabivaka spb @ victori square…',
#  '5b338cf0a5d973963e172c53': 'st petersburg name bar the…',
#  '5b338cf1a5d973963e1732a0': 'футбол @ europ moscow',
#  '5b338d9018248d8b6c9609cb': 'stand @ saint petersburg russia',
#  '5b338d9018248d8b6c960aa5': 'activist kiril kotov wa arrest day picket world cup',
#  '5b338d9118248d8b6c960c70': 'qajar woman mid- average…',
#  '5b338d9318248d8b6c961d86': 'nuha world cup russia',
#  '5b338d9318248d8b6c961fd6': 'blue island green ocean skydom skyabove…',
#  '5b338d9518248d8b6c962753': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b338d9518248d8b6c9627e4': 'world cup russia welcom world',
#  '5b338d9518248d8b6c962996': 'catch my…',
#  '5b338d9618248d8b6c962e47': 'share thi tbt in…',
#  '5b338d9618248d8b6c963009': 'k+ googl search world cup schedul old',
#  '5b338d9618248d8b6c96307d': 'worldcup zabivaka spb @ victori square…',
#  '5b338d9718248d8b6c96346d': 'st petersburg name bar the…',
#  '5b338d9818248d8b6c963aba': 'футбол @ europ moscow',
#  '5b338d9818248d8b6c963f71': 'long st petersburg grand for…',
#  '5b338d9918248d8b6c9641e2': 'throwback throwbackthursday russia sede del…',
#  '5b338d9918248d8b6c964650': 'see romeo juliet one oldest…',
#  '5b338d9a18248d8b6c964953': 'post video @ luzhniki stadium',
#  '5b338d9b18248d8b6c964e35': 'fifa world cup russia',
#  '5b338d9c18248d8b6c9653f0': 'post photo @ luzhniki stadium',
#  '5b338d9e18248d8b6c96613e': 'present wip nocturne…',
#  '5b338da018248d8b6c96704a': '-fifa world cup russia …',
#  '5b338dc1dd60b8bb6b466aa7': 'stand @ saint petersburg russia',
#  '5b338dc1dd60b8bb6b466b81': 'activist kiril kotov wa arrest day picket world cup',
#  '5b338dc2dd60b8bb6b466d4c': 'qajar woman mid- average…',
#  '5b338dc4dd60b8bb6b467e62': 'nuha world cup russia',
#  '5b338dc4dd60b8bb6b4680b2': 'blue island green ocean skydom skyabove…',
#  '5b338dc5dd60b8bb6b46882f': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b338dc6dd60b8bb6b4688c0': 'world cup russia welcom world',
#  '5b338dc6dd60b8bb6b468a72': 'catch my…',
#  '5b338dc6dd60b8bb6b468f23': 'share thi tbt in…',
#  '5b338dc7dd60b8bb6b4690e5': 'k+ googl search world cup schedul old',
#  '5b338dc7dd60b8bb6b469159': 'worldcup zabivaka spb @ victori square…',
#  '5b338dc7dd60b8bb6b469549': 'st petersburg name bar the…',
#  '5b338dc8dd60b8bb6b469b96': 'футбол @ europ moscow',
#  '5b338dc9dd60b8bb6b46a04d': 'long st petersburg grand for…',
#  '5b338dc9dd60b8bb6b46a2be': 'throwback throwbackthursday russia sede del…',
#  '5b338de9a67e600911c7d6a7': 'stand @ saint petersburg russia',
#  '5b338deaa67e600911c7d781': 'activist kiril kotov wa arrest day picket world cup',
#  '5b338deaa67e600911c7d94c': 'qajar woman mid- average…',
#  '5b338deca67e600911c7ea62': 'nuha world cup russia',
#  '5b338deda67e600911c7ecb2': 'blue island green ocean skydom skyabove…',
#  '5b338deea67e600911c7f42f': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b338deea67e600911c7f4c0': 'world cup russia welcom world',
#  '5b338deea67e600911c7f672': 'catch my…',
#  '5b338defa67e600911c7fb23': 'share thi tbt in…',
#  '5b338defa67e600911c7fce5': 'k+ googl search world cup schedul old',
#  '5b338defa67e600911c7fd59': 'worldcup zabivaka spb @ victori square…',
#  '5b338df0a67e600911c80149': 'st petersburg name bar the…',
#  '5b338df1a67e600911c80796': 'футбол @ europ moscow',
#  '5b338df2a67e600911c80c4d': 'long st petersburg grand for…',
#  '5b338df2a67e600911c80ebe': 'throwback throwbackthursday russia sede del…',
#  '5b338df3a67e600911c8132c': 'see romeo juliet one oldest…',
#  '5b338df3a67e600911c8162f': 'post video @ luzhniki stadium',
#  '5b338df4a67e600911c81b11': 'fifa world cup russia',
#  '5b338df5a67e600911c820cc': 'post photo @ luzhniki stadium',
#  '5b338df7a67e600911c82e1a': 'present wip nocturne…',
#  '5b338e121d31d327ec851cf5': 'stand @ saint petersburg russia',
#  '5b338e121d31d327ec851dcf': 'activist kiril kotov wa arrest day picket world cup',
#  '5b338e131d31d327ec851f9a': 'qajar woman mid- average…',
#  '5b338e181d31d327ec8530b0': 'nuha world cup russia',
#  '5b338e191d31d327ec853300': 'blue island green ocean skydom skyabove…',
#  '5b338e1f1d31d327ec853a7d': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b338e1f1d31d327ec853b0e': 'world cup russia welcom world',
#  '5b338e211d31d327ec853cc0': 'catch my…',
#  '5b338e251d31d327ec854171': 'share thi tbt in…',
#  '5b338e261d31d327ec854333': 'k+ googl search world cup schedul old',
#  '5b338e261d31d327ec8543a7': 'worldcup zabivaka spb @ victori square…',
#  '5b338e291d31d327ec854797': 'st petersburg name bar the…',
#  '5b338e2e1d31d327ec854de4': 'футбол @ europ moscow',
#  '5b338e321d31d327ec85529b': 'long st petersburg grand for…',
#  '5b338e341d31d327ec85550c': 'throwback throwbackthursday russia sede del…',
#  '5b338e371d31d327ec85597a': 'see romeo juliet one oldest…',
#  '5b33972489eb16c8e73c9c79': 'stand @ saint petersburg russia',
#  '5b33972489eb16c8e73c9d53': 'activist kiril kotov wa arrest day picket world cup',
#  '5b33972489eb16c8e73c9f1e': 'qajar woman mid- average…',
#  '5b33972789eb16c8e73cb034': 'nuha world cup russia',
#  '5b33972789eb16c8e73cb284': 'blue island green ocean skydom skyabove…',
#  '5b33972889eb16c8e73cba01': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b33972889eb16c8e73cba92': 'world cup russia welcom world',
#  '5b33972889eb16c8e73cbc44': 'catch my…',
#  '5b33972989eb16c8e73cc0f5': 'share thi tbt in…',
#  '5b33972a89eb16c8e73cc2b7': 'k+ googl search world cup schedul old',
#  '5b33972a89eb16c8e73cc32b': 'worldcup zabivaka spb @ victori square…',
#  '5b33972a89eb16c8e73cc71b': 'st petersburg name bar the…',
#  '5b33972b89eb16c8e73ccd68': 'футбол @ europ moscow',
#  '5b33972c89eb16c8e73cd21f': 'long st petersburg grand for…',
#  '5b33972c89eb16c8e73cd490': 'throwback throwbackthursday russia sede del…',
#  '5b33972d89eb16c8e73cd8fe': 'see romeo juliet one oldest…',
#  '5b33972d89eb16c8e73cdc01': 'post video @ luzhniki stadium',
#  '5b33972e89eb16c8e73ce0e3': 'fifa world cup russia',
#  '5b33972f89eb16c8e73ce69e': 'post photo @ luzhniki stadium',
#  '5b33973189eb16c8e73cf3ec': 'present wip nocturne…',
#  '5b339749d601daaa3ba499c7': 'stand @ saint petersburg russia',
#  '5b339749d601daaa3ba49aa1': 'activist kiril kotov wa arrest day picket world cup',
#  '5b339749d601daaa3ba49c6c': 'qajar woman mid- average…',
#  '5b33974cd601daaa3ba4ad82': 'nuha world cup russia',
#  '5b33974cd601daaa3ba4afd2': 'blue island green ocean skydom skyabove…',
#  '5b33974dd601daaa3ba4b74f': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b33974dd601daaa3ba4b7e0': 'world cup russia welcom world',
#  '5b33974dd601daaa3ba4b992': 'catch my…',
#  '5b33974ed601daaa3ba4be43': 'share thi tbt in…',
#  '5b33974fd601daaa3ba4c005': 'k+ googl search world cup schedul old',
#  '5b33974fd601daaa3ba4c079': 'worldcup zabivaka spb @ victori square…',
#  '5b33974fd601daaa3ba4c469': 'st petersburg name bar the…',
#  '5b339750d601daaa3ba4cab6': 'футбол @ europ moscow',
#  '5b339751d601daaa3ba4cf6d': 'long st petersburg grand for…',
#  '5b339751d601daaa3ba4d1de': 'throwback throwbackthursday russia sede del…',
#  '5b339752d601daaa3ba4d64c': 'see romeo juliet one oldest…',
#  '5b339a9339e106ad7f06b8d1': 'stand @ saint petersburg russia',
#  '5b339a9339e106ad7f06b9ab': 'activist kiril kotov wa arrest day picket world cup',
#  '5b339a9439e106ad7f06bb76': 'qajar woman mid- average…',
#  '5b339a9639e106ad7f06cc8c': 'nuha world cup russia',
#  '5b339a9739e106ad7f06cedc': 'blue island green ocean skydom skyabove…',
#  '5b339a9839e106ad7f06d659': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b339a9839e106ad7f06d6ea': 'world cup russia welcom world',
#  '5b339a9839e106ad7f06d89c': 'catch my…',
#  '5b339a9939e106ad7f06dd4d': 'share thi tbt in…',
#  '5b339a9939e106ad7f06df0f': 'k+ googl search world cup schedul old',
#  '5b339a9939e106ad7f06df83': 'worldcup zabivaka spb @ victori square…',
#  '5b339a9a39e106ad7f06e373': 'st petersburg name bar the…',
#  '5b339a9b39e106ad7f06e9c0': 'футбол @ europ moscow',
#  '5b339a9b39e106ad7f06ee77': 'long st petersburg grand for…',
#  '5b339a9c39e106ad7f06f0e8': 'throwback throwbackthursday russia sede del…',
#  '5b339a9d39e106ad7f06f556': 'see romeo juliet one oldest…',
#  '5b339a9d39e106ad7f06f859': 'post video @ luzhniki stadium',
#  '5b339a9e39e106ad7f06fd3b': 'fifa world cup russia',
#  '5b339a9f39e106ad7f0702f6': 'post photo @ luzhniki stadium',
#  '5b339aadb9b8b28beb66d91c': 'stand @ saint petersburg russia',
#  '5b339aadb9b8b28beb66d9f6': 'activist kiril kotov wa arrest day picket world cup',
#  '5b339aadb9b8b28beb66dbc1': 'qajar woman mid- average…',
#  '5b339aafb9b8b28beb66ecd7': 'nuha world cup russia',
#  '5b339ab0b9b8b28beb66ef27': 'blue island green ocean skydom skyabove…',
#  '5b339ab1b9b8b28beb66f6a4': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b339ab1b9b8b28beb66f735': 'world cup russia welcom world',
#  '5b339ab1b9b8b28beb66f8e7': 'catch my…',
#  '5b339ab2b9b8b28beb66fd98': 'share thi tbt in…',
#  '5b339ab3b9b8b28beb66ff5a': 'k+ googl search world cup schedul old',
#  '5b339ab3b9b8b28beb66ffce': 'worldcup zabivaka spb @ victori square…',
#  '5b339ab3b9b8b28beb6703be': 'st petersburg name bar the…',
#  '5b339ab4b9b8b28beb670a0b': 'футбол @ europ moscow',
#  '5b339ab5b9b8b28beb670ec2': 'long st petersburg grand for…',
#  '5b339ab5b9b8b28beb671133': 'throwback throwbackthursday russia sede del…',
#  '5b339ab6b9b8b28beb6715a1': 'see romeo juliet one oldest…',
#  '5b339ab6b9b8b28beb6718a4': 'post video @ luzhniki stadium',
#  '5b339b584c1d14adeab6aaea': 'stand @ saint petersburg russia',
#  '5b339b584c1d14adeab6abc4': 'activist kiril kotov wa arrest day picket world cup',
#  '5b339b584c1d14adeab6ad8f': 'qajar woman mid- average…',
#  '5b339b5a4c1d14adeab6bea5': 'nuha world cup russia',
#  '5b339b5a4c1d14adeab6c0f5': 'blue island green ocean skydom skyabove…',
#  '5b339b5b4c1d14adeab6c872': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b339b5b4c1d14adeab6c903': 'world cup russia welcom world',
#  '5b339b5b4c1d14adeab6cab5': 'catch my…',
#  '5b339b5c4c1d14adeab6cf66': 'share thi tbt in…',
#  '5b339b5c4c1d14adeab6d128': 'k+ googl search world cup schedul old',
#  '5b339b5c4c1d14adeab6d19c': 'worldcup zabivaka spb @ victori square…',
#  '5b339b5c4c1d14adeab6d58c': 'st petersburg name bar the…',
#  '5b339b5d4c1d14adeab6dbd9': 'футбол @ europ moscow',
#  '5b339b5e4c1d14adeab6e090': 'long st petersburg grand for…',
#  '5b339b5e4c1d14adeab6e301': 'throwback throwbackthursday russia sede del…',
#  '5b339b5f4c1d14adeab6e76f': 'see romeo juliet one oldest…',
#  '5b339b5f4c1d14adeab6ea72': 'post video @ luzhniki stadium',
#  '5b339b604c1d14adeab6ef54': 'fifa world cup russia',
#  '5b339b604c1d14adeab6f50f': 'post photo @ luzhniki stadium',
#  '5b339b624c1d14adeab7025d': 'present wip nocturne…',
#  '5b339b7b553042fb0f7a11f7': 'stand @ saint petersburg russia',
#  '5b339b7b553042fb0f7a12d1': 'activist kiril kotov wa arrest day picket world cup',
#  '5b339b7b553042fb0f7a149c': 'qajar woman mid- average…',
#  '5b339b7e553042fb0f7a25b2': 'nuha world cup russia',
#  '5b339b7e553042fb0f7a2802': 'blue island green ocean skydom skyabove…',
#  '5b339b7f553042fb0f7a2f7f': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b339b7f553042fb0f7a3010': 'world cup russia welcom world',
#  '5b339b7f553042fb0f7a31c2': 'catch my…',
#  '5b339b80553042fb0f7a3673': 'share thi tbt in…',
#  '5b339b80553042fb0f7a3835': 'k+ googl search world cup schedul old',
#  '5b339b80553042fb0f7a38a9': 'worldcup zabivaka spb @ victori square…',
#  '5b339b81553042fb0f7a3c99': 'st petersburg name bar the…',
#  '5b339b81553042fb0f7a42e6': 'футбол @ europ moscow',
#  '5b339b82553042fb0f7a479d': 'long st petersburg grand for…',
#  '5b339b82553042fb0f7a4a0e': 'throwback throwbackthursday russia sede del…',
#  '5b339b83553042fb0f7a4e7c': 'see romeo juliet one oldest…',
#  '5b339b83553042fb0f7a517f': 'post video @ luzhniki stadium',
#  '5b339b84553042fb0f7a5661': 'fifa world cup russia',
#  '5b339b85553042fb0f7a5c1c': 'post photo @ luzhniki stadium',
#  '5b339b95f49d6840be1b4d81': 'stand @ saint petersburg russia',
#  '5b339b95f49d6840be1b4e5b': 'activist kiril kotov wa arrest day picket world cup',
#  '5b339b96f49d6840be1b5026': 'qajar woman mid- average…',
#  '5b339b98f49d6840be1b613c': 'nuha world cup russia',
#  '5b339b98f49d6840be1b638c': 'blue island green ocean skydom skyabove…',
#  '5b339b9af49d6840be1b6b09': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b339b9af49d6840be1b6b9a': 'world cup russia welcom world',
#  '5b339b9af49d6840be1b6d4c': 'catch my…',
#  '5b339b9bf49d6840be1b71fd': 'share thi tbt in…',
#  '5b339b9bf49d6840be1b73bf': 'k+ googl search world cup schedul old',
#  '5b339b9bf49d6840be1b7433': 'worldcup zabivaka spb @ victori square…',
#  '5b339b9cf49d6840be1b7823': 'st petersburg name bar the…',
#  '5b339b9df49d6840be1b7e70': 'футбол @ europ moscow',
#  '5b339b9ef49d6840be1b8327': 'long st petersburg grand for…',
#  '5b339b9ef49d6840be1b8598': 'throwback throwbackthursday russia sede del…',
#  '5b339b9ff49d6840be1b8a06': 'see romeo juliet one oldest…',
#  '5b339b9ff49d6840be1b8d09': 'post video @ luzhniki stadium',
#  '5b339ba0f49d6840be1b91eb': 'fifa world cup russia',
#  '5b339ba1f49d6840be1b97a6': 'post photo @ luzhniki stadium',
#  '5b339ba3f49d6840be1ba4f4': 'present wip nocturne…',
#  '5b339bb20796f48ac445f605': 'stand @ saint petersburg russia',
#  '5b339bb30796f48ac445f6df': 'activist kiril kotov wa arrest day picket world cup',
#  '5b339bb30796f48ac445f8aa': 'qajar woman mid- average…',
#  '5b339bbc0796f48ac44609c0': 'nuha world cup russia',
#  '5b339bbe0796f48ac4460c10': 'blue island green ocean skydom skyabove…',
#  '5b339bc40796f48ac446138d': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b339bc40796f48ac446141e': 'world cup russia welcom world',
#  '5b339bc60796f48ac44615d0': 'catch my…',
#  '5b339bc90796f48ac4461a81': 'share thi tbt in…',
#  '5b339bcb0796f48ac4461c43': 'k+ googl search world cup schedul old',
#  '5b339bcb0796f48ac4461cb7': 'worldcup zabivaka spb @ victori square…',
#  '5b339bce0796f48ac44620a7': 'st petersburg name bar the…',
#  '5b339bd30796f48ac44626f4': 'футбол @ europ moscow',
#  '5b339bd70796f48ac4462bab': 'long st petersburg grand for…',
#  '5b339bd90796f48ac4462e1c': 'throwback throwbackthursday russia sede del…',
#  '5b339bdd0796f48ac446328a': 'see romeo juliet one oldest…',
#  '5b339bdf0796f48ac446358d': 'post video @ luzhniki stadium',
#  '5b339be30796f48ac4463a6f': 'fifa world cup russia',
#  '5b339be80796f48ac446402a': 'post photo @ luzhniki stadium',
#  '5b339c419015b97c82730217': 'stand @ saint petersburg russia',
#  '5b339c429015b97c827302f1': 'activist kiril kotov wa arrest day picket world cup',
#  '5b339c429015b97c827304bc': 'qajar woman mid- average…',
#  '5b339c449015b97c827315d2': 'nuha world cup russia',
#  '5b339c459015b97c82731822': 'blue island green ocean skydom skyabove…',
#  '5b339c469015b97c82731f9f': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b339c469015b97c82732030': 'world cup russia welcom world',
#  '5b339c469015b97c827321e2': 'catch my…',
#  '5b339c479015b97c82732693': 'share thi tbt in…',
#  '5b339c479015b97c82732855': 'k+ googl search world cup schedul old',
#  '5b339c479015b97c827328c9': 'worldcup zabivaka spb @ victori square…',
#  '5b339c489015b97c82732cb9': 'st petersburg name bar the…',
#  '5b339c499015b97c82733306': 'футбол @ europ moscow',
 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b33a0c2efd28ca291d4e621': 'world cup russia welcom world',
#  '5b33a0c3efd28ca291d4e7d3': 'catch my…',
#  '5b33a0c3efd28ca291d4ec84': 'share thi tbt in…',
#  '5b33a0c4efd28ca291d4ee46': 'k+ googl search world cup schedul old',
#  '5b33a0c4efd28ca291d4eeba': 'worldcup zabivaka spb @ victori square…',
#  '5b33a0c4efd28ca291d4f2aa': 'st petersburg name bar the…',
#  '5b33a0c5efd28ca291d4f8f7': 'футбол @ europ moscow',
#  '5b33a0c6efd28ca291d4fdae': 'long st petersburg grand for…',
#  '5b33a0c6efd28ca291d5001f': 'throwback throwbackthursday russia sede del…',
#  '5b33a0d230a944d3b8173de0': 'stand @ saint petersburg russia',
#  '5b33a0d230a944d3b8173eba': 'activist kiril kotov wa arrest day picket world cup',
#  '5b33a0d230a944d3b8174085': 'qajar woman mid- average…',
#  '5b33a0d530a944d3b817519b': 'nuha world cup russia',
#  '5b33a0d530a944d3b81753eb': 'blue island green ocean skydom skyabove…',
#  '5b33a0d630a944d3b8175b68': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b33a0d630a944d3b8175bf9': 'world cup russia welcom world',
#  '5b33a0d630a944d3b8175dab': 'catch my…',
#  '5b33a0d730a944d3b817625c': 'share thi tbt in…',
#  '5b33a0d830a944d3b817641e': 'k+ googl search world cup schedul old',
#  '5b33a0d830a944d3b8176492': 'worldcup zabivaka spb @ victori square…',
#  '5b33a0d830a944d3b8176882': 'st petersburg name bar the…',
#  '5b33a0d930a944d3b8176ecf': 'футбол @ europ moscow',
#  '5b33a0da30a944d3b8177386': 'long st petersburg grand for…',
#  '5b33a0da30a944d3b81775f7': 'throwback throwbackthursday russia sede del…',
#  '5b33a0db30a944d3b8177a65': 'see romeo juliet one oldest…',
#  '5b33a0db30a944d3b8177d68': 'post video @ luzhniki stadium',
#  '5b33a0dc30a944d3b817824a': 'fifa world cup russia',
#  '5b33a0de30a944d3b8178805': 'post photo @ luzhniki stadium',
#  '5b33a0e030a944d3b8179553': 'present wip nocturne…',
#  '5b33a0ee066028ac770d8921': 'stand @ saint petersburg russia',
#  '5b33a0ee066028ac770d89fb': 'activist kiril kotov wa arrest day picket world cup',
#  '5b33a0ef066028ac770d8bc6': 'qajar woman mid- average…',
#  '5b33a0f1066028ac770d9cdc': 'nuha world cup russia',
#  '5b33a0f2066028ac770d9f2c': 'blue island green ocean skydom skyabove…',
#  '5b33a0f3066028ac770da6a9': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b33a0f3066028ac770da73a': 'world cup russia welcom world',
#  '5b33a0f3066028ac770da8ec': 'catch my…',
#  '5b33a0f4066028ac770dad9d': 'share thi tbt in…',
#  '5b33a0f4066028ac770daf5f': 'k+ googl search world cup schedul old',
#  '5b33a0f4066028ac770dafd3': 'worldcup zabivaka spb @ victori square…',
#  '5b33a0f5066028ac770db3c3': 'st petersburg name bar the…',
#  '5b33a0f6066028ac770dba10': 'футбол @ europ moscow',
#  '5b33a0f7066028ac770dbec7': 'long st petersburg grand for…',
#  '5b33a0f7066028ac770dc138': 'throwback throwbackthursday russia sede del…',
#  '5b33a0f8066028ac770dc5a6': 'see romeo juliet one oldest…',
#  '5b33a0f9066028ac770dc8a9': 'post video @ luzhniki stadium',
#  '5b34b51b066028ac770dce38': 'stand @ saint petersburg russia',
#  '5b34b61cf7357da992c92ae9': 'stand @ saint petersburg russia',
#  '5b34b61cf7357da992c92bc3': 'activist kiril kotov wa arrest day picket world cup',
#  '5b34b61df7357da992c92d8e': 'qajar woman mid- average…',
#  '5b34b61ff7357da992c93ea4': 'nuha world cup russia',
#  '5b34b61ff7357da992c940f4': 'blue island green ocean skydom skyabove…',
#  '5b34b620f7357da992c94871': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b34b621f7357da992c94902': 'world cup russia welcom world',
#  '5b34b621f7357da992c94ab4': 'catch my…',
#  '5b34b622f7357da992c94f65': 'share thi tbt in…',
#  '5b34b622f7357da992c95127': 'k+ googl search world cup schedul old',
#  '5b34b622f7357da992c9519b': 'worldcup zabivaka spb @ victori square…',
#  '5b34b623f7357da992c9558b': 'st petersburg name bar the…',
#  '5b34b623f7357da992c95bd8': 'футбол @ europ moscow',
#  '5b34b624f7357da992c9608f': 'long st petersburg grand for…',
#  '5b34b625f7357da992c96300': 'throwback throwbackthursday russia sede del…',
#  '5b34b625f7357da992c9676e': 'see romeo juliet one oldest…',
#  '5b34b626f7357da992c96a71': 'post video @ luzhniki stadium',
#  '5b34b626f7357da992c96f53': 'fifa world cup russia',
#  '5b34b628f7357da992c9750e': 'post photo @ luzhniki stadium',
#  '5b34b62af7357da992c9825c': 'present wip nocturne…',
#  '5b34b62cf7357da992c99168': '-fifa world cup russia …',
#  '5b34b62ef7357da992c9a118': 'fifa fan fest zone saint-petersburg',
#  '5b34b62ff7357da992c9a358': 'welcom world cup russia group match…',
#  '5b34b62ff7357da992c9a6d9': 'got fli russia world cup hope find support african team',
#  '5b34b630f7357da992c9a98a': 'god bless morocco : morocco : :morocco : :morocco : footbal worldcup…',
#  '5b34b630f7357da992c9b0b0': 'today day : clapping_hand : world cup russia our…',
#  '5b34b633f7357da992c9c1ce': 'today day : clapping_hand : world cup russia our…',
#  '5b34b634f7357da992c9cd37': 'putin lad : face_with_tears_of_joy : :rolling_on_the_floor_laugh : russiaworldcup',
#  '5b34b635f7357da992c9d4a6': 'first game world cup russia : russia : and…',
#  '5b34b636f7357da992c9d812': 'let game begin happi world cup…',
#  '5b34b680dfadbd048dd711fe': 'stand @ saint petersburg russia',
#  '5b34b680dfadbd048dd712d8': 'activist kiril kotov wa arrest day picket world cup',
#  '5b34b681dfadbd048dd714a3': 'qajar woman mid- average…',
#  '5b34b683dfadbd048dd725b9': 'nuha world cup russia',
#  '5b34b684dfadbd048dd72809': 'blue island green ocean skydom skyabove…',
#  '5b34b8130b127f02c7feecfb': 'stand @ saint petersburg russia',
#  '5b34b8130b127f02c7feedd5': 'activist kiril kotov wa arrest day picket world cup',
#  '5b34b8130b127f02c7feefa0': 'qajar woman mid- average…',
#  '5b34b8150b127f02c7ff00b6': 'nuha world cup russia',
#  '5b34b8150b127f02c7ff0306': 'blue island green ocean skydom skyabove…',
#  '5b34b8160b127f02c7ff0a83': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b34b8160b127f02c7ff0b14': 'world cup russia welcom world',
#  '5b34b8170b127f02c7ff0cc6': 'catch my…',
#  '5b34b8170b127f02c7ff1177': 'share thi tbt in…',
#  '5b34b8170b127f02c7ff1339': 'k+ googl search world cup schedul old',
#  '5b34b8170b127f02c7ff13ad': 'worldcup zabivaka spb @ victori square…',
#  '5b34b8180b127f02c7ff179d': 'st petersburg name bar the…',
#  '5b34b8190b127f02c7ff1dea': 'футбол @ europ moscow',
#  '5b34b81a0b127f02c7ff22a1': 'long st petersburg grand for…',
#  '5b34b81a0b127f02c7ff2512': 'throwback throwbackthursday russia sede del…',
#  '5b34b81a0b127f02c7ff2980': 'see romeo juliet one oldest…',
#  '5b34b81a0b127f02c7ff2c83': 'post video @ luzhniki stadium',
#  '5b34b81b0b127f02c7ff3165': 'fifa world cup russia',
#  '5b34b81c0b127f02c7ff3720': 'post photo @ luzhniki stadium',
#  '5b34b81e0b127f02c7ff446e': 'present wip nocturne…',
#  '5b34b81f0b127f02c7ff537a': '-fifa world cup russia …',
#  '5b34b9055c083c9dd2ac88f0': 'stand @ saint petersburg russia',
#  '5b34b9055c083c9dd2ac89ca': 'activist kiril kotov wa arrest day picket world cup',
#  '5b34b9055c083c9dd2ac8b95': 'qajar woman mid- average…',
#  '5b34b9085c083c9dd2ac9cab': 'nuha world cup russia',
#  '5b34b9085c083c9dd2ac9efb': 'blue island green ocean skydom skyabove…',
#  '5b34b926b18c7af0d30b10a0': 'stand @ saint petersburg russia',
#  '5b34b926b18c7af0d30b117a': 'activist kiril kotov wa arrest day picket world cup',
#  '5b34b926b18c7af0d30b1345': 'qajar woman mid- average…',
#  '5b34b929b18c7af0d30b245b': 'nuha world cup russia',
#  '5b34b929b18c7af0d30b26ab': 'blue island green ocean skydom skyabove…',
#  '5b34b92ab18c7af0d30b2e28': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b34b92ab18c7af0d30b2eb9': 'world cup russia welcom world',
#  '5b34b92ab18c7af0d30b306b': 'catch my…',
#  '5b34b92bb18c7af0d30b351c': 'share thi tbt in…',
#  '5b34b92cb18c7af0d30b36de': 'k+ googl search world cup schedul old',
#  '5b34b92cb18c7af0d30b3752': 'worldcup zabivaka spb @ victori square…',
#  '5b34b92cb18c7af0d30b3b42': 'st petersburg name bar the…',
#  '5b34b92cb18c7af0d30b418f': 'футбол @ europ moscow',
#  '5b34b92db18c7af0d30b4646': 'long st petersburg grand for…',
#  '5b34b92db18c7af0d30b48b7': 'throwback throwbackthursday russia sede del…',
#  '5b34b92eb18c7af0d30b4d25': 'see romeo juliet one oldest…',
#  '5b34b92eb18c7af0d30b5028': 'post video @ luzhniki stadium',
#  '5b34b92fb18c7af0d30b550a': 'fifa world cup russia',
#  '5b34b930b18c7af0d30b5ac5': 'post photo @ luzhniki stadium',
#  '5b34b931b18c7af0d30b6813': 'present wip nocturne…',
#  '5b34ba4adb76ff6a3a9b8ee5': 'stand @ saint petersburg russia',
#  '5b34ba4adb76ff6a3a9b8fbf': 'activist kiril kotov wa arrest day picket world cup',
#  '5b34ba4bdb76ff6a3a9b918a': 'qajar woman mid- average…',
#  '5b34ba4ddb76ff6a3a9ba2a0': 'nuha world cup russia',
#  '5b34ba4edb76ff6a3a9ba4f0': 'blue island green ocean skydom skyabove…',
#  '5b34ba4fdb76ff6a3a9bac6d': 'world cup cocain marijuana amp heroin allow russia ( detail )',
#  '5b34ba4fdb76ff6a3a9bacfe': 'world cup russia welcom world',
#  '5b34ba4fdb76ff6a3a9baeb0': 'catch my…',
# ...
#  '5b34bbf654127b2bacb6c51e': 'fifa fan fest zone saint-petersburg',
#  '5b34bbf654127b2bacb6c760': 'welcom world cup russia group match…',
#  '5b34bbf654127b2bacb6cae0': 'got fli russia world cup hope find support african team',
#  '5b34bbf654127b2bacb6cd91': 'god bless morocco : morocco : :morocco : :morocco : footbal worldcup…',
#  '5b34bbf754127b2bacb6d4b7': 'today day : clapping_hand : world cup russia our…',
#  '5b34bbf754127b2bacb6e5d4': 'today day : clapping_hand : world cup russia our…',
#  '5b34bbf854127b2bacb6f13e': 'putin lad : face_with_tears_of_joy : :rolling_on_the_floor_laugh : russiaworldcup',
#  '5b34bbf954127b2bacb6f8ac': 'first game world cup russia : russia : and…',
#  '5b34bbf954127b2bacb6fc18': 'let game begin happi world cup…',
#  '5b34bbf954127b2bacb6fdc4': 'world cup russia moscow costa rica : costa_rica : …',
#  '5b34bbf954127b2bacb6fe89': 'watch open ceremoni world cup russia russia vs saudi @ buffalowingsjo fifaworldcup russia worldcup…',
#  '5b34bbf954127b2bacb703f8': 'let kick : soccer_bal : ️ world cup russia…',
#  '5b34bbfa54127b2bacb706ae': 'world cup begin minut start russia vs saudi arabia god grace pm',
#  '5b34bbfa54127b2bacb70e71': 'banner support oleg sentsov near luzhniki stadium today',
#  '5b34bbfb54127b2bacb71b81': ': united_st : win world cup russia do…',
#  '5b34bbfb54127b2bacb728f6': 'st goal worldcup teamrussia @ …',
#  '5b34bbfb54127b2bacb72b70': 'come fifafanfest moscow lets…',
#  '5b34bbfc54127b2bacb7387d': 'today great…',
#  '5b34bbfe54127b2bacb753a8': 'world cup rusia russia vs saudi…',
#  '5b34bbfe54127b2bacb753af': 'post photo @ fisht olymp stadium',
#  '5b34bbfe54127b2bacb75ae9': 'let go guy ru worldcup fifafanfest…',
#  '5b34bbff54127b2bacb767c3': 'world cup russia ban nigerian support bring live chicken stadium',
#  '5b34bc0054127b2bacb76bdf': '',
#  '5b34bc0054127b2bacb7718e': 'wolv riseagainst @ saint…',
#  '5b34bc0154127b2bacb77c13': '@ chachagq saint petersburg st-petersburg',
#  '5b34bc0154127b2bacb78253': 'enjoy world cup russia empanada top…',
#  '5b34bc0154127b2bacb784e8': 'photo taken mrs_katezhna arch…',
#  '5b34bc0254127b2bacb78a21': 'alway friday : fire : vsco spb saintpetersburg…',
#  '5b34bc0254127b2bacb7929d': '',
#  '5b34bc0254127b2bacb79581': ': soccer_bal : ️fifa world cup : soccer_bal : ️ : russia : russia : russia : …',
#  '5b34bc0354127b2bacb799ef': 'proud brother moment - thi oldest bro -…',
#  '5b34bc0554127b2bacb7bbfb': 'fifa world cup russia team onli …',
#  '5b34bc0554127b2bacb7c0d2': 'watch fifa world cup russia rest denc',
#  '5b34bc0554127b2bacb7c38f': ': chart_increas : fifa world cup russia group stage fixtur ( npt )',
#  '5b34bc0954127b2bacb7facd': '【 : trophi : world cup : soccer_bal : ️russia : russia : 】…',
#  '5b34bc0a54127b2bacb8062c': 'soccer world cup russia come have…',
#  '5b34bc0a54127b2bacb80653': '@ teamrussia st mention вместемыкоманда appear tl trend topic russia trndnl',
#  '5b34bc0a54127b2bacb80665': 'tweet impact вместемыкоманда trend wa publish @ teamrussia',
#  '5b34bc0a54127b2bacb8066f': 'verifi account help turn вместемыкоманда trend topic account @ teamrussia @ rfpl amp @ jordanhalford',
#  '5b34bc0d54127b2bacb817df': 'let ‘ gooo : sign_of_the_horn : :smiling_face_with_sunglass : wm : red_heart : ️ basel live : zany_fac : vlog…',
#  '5b34bc0d54127b2bacb81942': 'remark player fifa world cup russia quot',
#  '5b34bc0e54127b2bacb81b2d': 'fifa world cup open ceremoni russia : soccer_bal : :soccer_bal : :soccer_bal : :soccer_bal : :person_run : :person_run : :person_run : :trophi : :trophi :',
#  '5b34bc0e54127b2bacb81d6b': 'iran fan wait tomorrow @ saint…',
#  '5b34bc0e54127b2bacb81fc6': '@ fifaworldcup @ teamrussia mani mani congratul : bouquet : :bouquet : @ teamrussia : russia : worldcup russiaworldcup @ fifaworldcup',
#  '5b34bc0e54127b2bacb820b9': 'welcom fifa world cup russia open match : russia : :soccer_bal :',
#  '5b34bc0e54127b2bacb829ba': 'throwback bewitch lure russian gem…',
#  '5b34bc0f54127b2bacb82b9f': 'moroccan rival veri friendli with…',
#  '5b34bc0f54127b2bacb83861': 'boss thi russia : russia : :russia :',
#  '5b34bc1054127b2bacb83bf7': 'world cup russia thump saudi arabia style',
#  '5b34bc1054127b2bacb848a1': 'wa amaz day recal much sunny…',
#  '5b34bc1154127b2bacb85249': 'post photo @ luzhniki stadium',
#  '5b34bc1154127b2bacb85533': 'world cup russia saudi arabia start line-up',
#  '5b34bc1154127b2bacb8554a': 'world cup russia welcom world',
#  '5b34bc1254127b2bacb85590': 'world cup russia iuri gazinski score first goal',
#  '5b34bc1254127b2bacb85a24': 'uniti saint petersburg',
#  '5b34bc1354127b2bacb86579': 'world cup russia stop nigerian fan bring live chicken stadium',
#  '5b34bc1354127b2bacb86df5': 'fifa world cup russia kick llc…',
#  '5b34bc1354127b2bacb870e2': 'great start host teamrussia tonight…',
#  '5b34bc1454127b2bacb8768e': 'video photo first day a…',
#  '5b34bc1454127b2bacb87b84': 'amaz @ robbiewilliam open thi month- long…',
#  '5b34bc1454127b2bacb87b97': 'caff prego',
#  '5b34bc1454127b2bacb87e14': 'dog play guitar ) beutifulldogs…',
#  '5b34bc1454127b2bacb87e3d': 'ronaldo @ ronaldo fifa…',
#  '5b34bc1454127b2bacb880fc': 'russia today world cup thi day playing…',
#  '5b34bc1554127b2bacb88615': 'finally…',
#  '5b34bc1554127b2bacb88bab': 'russia gazinski score first goal world cup',
#  '5b34bc1554127b2bacb891b5': 'beauti st…',
#  '5b34bc1654127b2bacb89bc1': 'squat jump @ saint petersburg russia',
#  '5b34bc1754127b2bacb8a56c': 'one one @ peter paul fortress',
#  '5b34bc1754127b2bacb8a607': 'st bean saint petersburg',
#  '5b34bc1854127b2bacb8b0bc': 'phenomen game russia go ahead…',
#  '5b34bc1854127b2bacb8b4fa': 'fifa world cup russia moscow…',
#  '5b34bc1854127b2bacb8ba23': 'sick af friend take you…',
#  '5b34bc1854127b2bacb8bacd': 'st day world cup russia done…',
#  '5b34bc1954127b2bacb8bc0f': 'world cup russia',
#  '5b34bc1954127b2bacb8be4f': 'ващенорм @ yeas…',
#  '5b34bc1a54127b2bacb8c9d1': 'st petersburg beauti citi rich…',
#  '5b34bc1a54127b2bacb8cce4': 'everyth need know world cup russia',
#  '5b34bc1a54127b2bacb8cef4': ': victory_hand : world cup bluffer guid everi team russia -',
#  '5b34bc1a54127b2bacb8cfb2': 'ligh dinner st…',
#  '5b34bc1b54127b2bacb8da6b': 'nationalflagday fifa world cup russia …',
#  '5b34bc1b54127b2bacb8e367': 'fifafanfestworldcupfootballrussiamoscow…',
#  '5b34bc1c54127b2bacb8e6fc': 'world cup : trophi : :england : спб saintpetersburg…',
#  '5b34bc1c54127b2bacb8e756': 'tbt dont care post thi befor all…',
#  '5b34bc1c54127b2bacb8e793': 'fifa world cup - russia destroy saudi…',
#  '5b34bc1c54127b2bacb8ea60': 'beauti st petersburg санктпетербург russia…',
#  '5b34bc1c54127b2bacb8eedb': 'fifafanfest @ fifa world cup -',
#  '5b34bc1d54127b2bacb8f343': 'thi mean thi mean : smiling_face_with_sunglass : saintptheselittl gangaremyfamili',
#  '5b34bc1d54127b2bacb8f36d': 'thi mean thi means…',
#  '5b34bc1d54127b2bacb9008c': '𝒂𝒏𝒅 𝒚𝒐𝒖 𝒍𝒍 𝒏𝒆𝒗𝒆𝒓…',
#  '5b34bc1e54127b2bacb90569': 'world cup russia start today…',
#  '5b34bc1e54127b2bacb906a9': 'updat saint petersburg gtf ( st petersburg russia )',
#  '5b34bc1f54127b2bacb90d1d': 'want work спб view latest open',
#  '5b34bc1f54127b2bacb914a3': 'world cup russia @',
#  '5b34bc1f54127b2bacb917ea': 'hire click appli princip sw qualiti eng -',
#  '5b34bc2054127b2bacb919af': 'hire click appli softwar engin -',
#  '5b34bc2054127b2bacb922c4': 'interest job спб thi could great fit',
#  '5b34bc2054127b2bacb92367': 'let go win world cup fifa russia…',
#  '5b34bc2054127b2bacb924dd': 'want work dell hire спб click detail',
#  '5b34bc2154127b2bacb92fbb': 'look work спб check thi job',
#  '5b34bc2154127b2bacb9325b': 'look work спб check thi job',
#  '5b34bc2254127b2bacb9344f': 'throwback stpetersburg mosqu : mosqu : russia i…',
#  '5b34bc2254127b2bacb936c1': 'urban inner space downtownstrol gates…',
#  '5b34bc2254127b2bacb937f4': 'vscocam spb sneaker offwhit bw @ babochka',
#  '5b34bc2254127b2bacb93d2a': 'mellow lonesome…',
#  '5b34bc2254127b2bacb93d89': ': woman_walking_light_skin_ton : :leaf_fluttering_in_wind : :sun : ️ @ saint…',
#  '5b34bc2254127b2bacb93fa5': 'thi job might great fit senior softwar qualiti engin -',
#  '5b34bc2254127b2bacb942dc': 'join dell team see latest job open',
#  '5b34bc2354127b2bacb949ff': 'saint petersburg - @ gov_spb st-petersburg',
#  '5b34bc2354127b2bacb94cf2': 'push-up : flexed_bicep : @ saint petersburg russia',
#  '5b34bc2354127b2bacb94e68': 'push : face_with_rolling_ey : @ saint petersburg russia',
#  '5b34bc2454127b2bacb95099': 'rt world cup russia real time ground footag - day ( tape )',
#  '5b34bc2454127b2bacb9532c': 'hire click appli senior softwar qualiti engin -',
#  '5b34bc2454127b2bacb95476': 'jess elli lingard : england : russia vsco…',
#  '5b34bc2454127b2bacb956cf': 'look work спб check thi job',
#  '5b34bc2454127b2bacb95a13': 'thi morn miler park imeni…',
#  '5b34bc2454127b2bacb95ed5': 'octopus garden…',
#  '5b34bc2554127b2bacb969a6': 'recommend anyon thi job senior softwar qualiti engin -',
#  '5b34bc2654127b2bacb96bb7': 'finish run km ms endomondo endorphin',
#  '5b34bc2654127b2bacb96c09': 'wa veri nice event famous…',
#  '5b34bc2654127b2bacb96df7': 'fifa world cup : round_pushpin : russia travel wanderlust…',
#  '5b34bc2654127b2bacb96eb2': 'fifa world cup : round_pushpin : russia travel wanderlust…',
#  '5b34bc2654127b2bacb9717a': 'vision futur artobject artmuza_spb…',
#  '5b34bc2654127b2bacb97251': 'luzhniki stadium moscow played…',
#  '5b34bc2654127b2bacb97392': 'post photo…',
#  '5b34bc2654127b2bacb9744f': 'match fifa world cup russia…',
#  '5b34bc2754127b2bacb9823e': 'fifa world cup russia russia…',
#  '5b34bc2854127b2bacb98729': 'fifa world cup start let have…',
#  '5b34bc2854127b2bacb98947': 'lift sky undersid photo…',
#  '5b34bc2a54127b2bacb9a223': 'readi rock riseagainst @ а green…',
#  '5b34bc2b54127b2bacb9af11': 'result want way of…',
#  '5b34bc2c54127b2bacb9c5c0': 'tmmr product offic',
#  '5b34bc2c54127b2bacb9c78d': 'saint petersburg sun goe for…',
#  '5b34bc2c54127b2bacb9c819': 'intern special building…',
#  '5b34bc2d54127b2bacb9cdc3': 'lift sky deadwal saintpetersburg…',
#  '5b34bc2e54127b2bacb9dbf1': 'keep quiet longer sing the…',
#  '5b34bc2e54127b2bacb9df3c': 'nike refus give player cleat adidas…',
#  '5b34bc2e54127b2bacb9e4c4': 'desd sochi con : red_heart : ️ en fisht olymp stadium',
#  '5b34bc2f54127b2bacb9ef63': 'stori md intellectualmassag ph…',
#  '5b34bc2f54127b2bacb9f312': 'gang da hood : red_circl : :anchor : ️ : black_circl : ️ primaonelov football…',
#  '5b34bc3054127b2bacb9f669': '¡vamo @ fifa world cup russia…',
#  '5b34bc3154127b2bacba01a2': 'teammat becom rival futbol frenzy…',
#  '5b34bc3154127b2bacba04d5': 'may heaven befor devil knows…',
#  '5b34bc3154127b2bacba0c56': 'sport techi hq fifa world cup russia…',
#  '5b34bc3254127b2bacba0f0b': 'dream unlik long for…',
#  '5b34bc3254127b2bacba12bc': 'hello world hello onli one song repeat today - new one imaginedragon : red_heart : ️ ( @ лахт…',
#  '5b34bc3254127b2bacba13ce': 'alreadi part muaythai @ saint…',
#  '5b34bc3254127b2bacba1456': 'show mine show yours…',
#  '5b34bc3254127b2bacba1786': 'feel heat hold your…',
#  '5b34bc3254127b2bacba190f': 'best team festiv life : red_heart : ️ : red_heart : ️ : red_heart : ️ guy of…',
#  '5b34bc3254127b2bacba1913': 'iranian soccer nation team - one team one…',
#  '5b34bc3354127b2bacba21d4': 'wth : iran : : flushed_fac : :flushed_fac : :flushed_fac : :flushed_fac : :flushed_fac : :winking_fac : :winking_fac : :winking_fac : gq gqmodel or…',
#  '5b34bc3354127b2bacba23b7': 'time : flexed_biceps_medium_skin_ton : :iran : :flexed_biceps_medium_skin_ton : …',
#  '5b34bc3354127b2bacba24c7': 'stori md intellectualmassag ph…',
#  '5b34bc3354127b2bacba2655': 'world cup russia go nippon…',
#  '5b34bc3354127b2bacba267b': 'two think will…',
#  '5b34bc3354127b2bacba2732': 'person worldcup : trophi : fifafanfest…',
#  '5b34bc3354127b2bacba29f8': 'go morocco …',
#  '5b34bc3454127b2bacba2a97': 'welcom world cup moscowrussia…',
#  '5b34bc3454127b2bacba2aca': 'awhil sinc seen name…',
#  '5b34bc3454127b2bacba2cad': 'line morroco vs iran worldcup…',
#  '5b34bc3454127b2bacba2cb5': 'see storm eye falling…',
#  '5b34bc3454127b2bacba309e': 'metro morocco fan @ stade de…',
#  '5b34bc3554127b2bacba3848': '@ fifawwc @ fisht olymp stadium',
#  '5b34bc3554127b2bacba3942': 'let get boy : iran : :iran : :iran : :iran : :iran : :iran : :iran : @ zenit arena…',
#  '5b34bc3554127b2bacba3ea8': 'stori md intellectualmassag ph…',
#  '5b34bc3554127b2bacba4478': 'lunch time : sushi : gustogram saint petersburg…',
#  '5b34bc3654127b2bacba48ec': 'repost @ riseagainst spb : purple_heart : @ saint…',
#  '5b34bc3654127b2bacba4930': 'post photo @ church savior on…',
#  '5b34bc3654127b2bacba4961': 'photo booth : camera_with_flash : say chees : zany_fac : galeria mall…',
#  '5b34bc3654127b2bacba4af3': 'drink stone xocoveza @ stonebrew @ insurgentebrew @ blinder',
#  '5b34bc3654127b2bacba4b03': 'finish run km ms endomondo endorphin',
#  '5b34bc3654127b2bacba50cd': 'world cup ghana coach stephen appiah reveal african countri well russia',
#  '5b34bc3754127b2bacba5157': 'sexi lexy…',
#  '5b34bc3854127b2bacba5e6c': 'morocco vs ir iran duel two black…',
#  '5b34bc3854127b2bacba6025': 'morocco vs ir iran duel two black…',
#  '5b34bc3854127b2bacba610a': 'fifa world cup russia …',
#  '5b34bc3854127b2bacba615c': 'staret fifaworldcup…',
#  '5b34bc3854127b2bacba6192': 'world cup russia group match day…',
#  '5b34bc3854127b2bacba634e': 'let laugh dive @ socceram worldcup…',
#  '5b34bc3854127b2bacba66f1': 'goal yet russiaworldcup',
#  '5b34bc3954127b2bacba6de5': 'blue sky sunni day downtown sky…',
#  '5b34bc3954127b2bacba6df9': 'one time ромеоиджульеттаавербуха @ …',
#  '5b34bc3954127b2bacba705a': 'post video @ zenit arena st petersburg',
#  '5b34bc3954127b2bacba76b1': 'stadium @ saint petersburg russia',
#  '5b34bc3a54127b2bacba7e0e': 'hardli home alway rep @ zenit arena st…',
#  '5b34bc3a54127b2bacba8264': 'finish cycl km hm endomondo endorphin',
#  '5b34bc3a54127b2bacba82aa': 'look deeper anyon ever has…',
#  '5b34bc3a54127b2bacba8439': 'late goal @ saint petersburg russia',
#  '5b34bc3a54127b2bacba8531': 'crave deep understand born outside…',
#  '5b34bc3a54127b2bacba86c2': 'adida : regist : football…',
#  '5b34bc3b54127b2bacba8a1d': 'late goal stop iran un winning…',
#  '5b34bc3b54127b2bacba8cd5': 'nation heartbeat iran @ zenit arena st…',
#  '5b34bc3b54127b2bacba8cf7': 'nation heartbeat iran @ zenit arena st…',
#  '5b34bc3b54127b2bacba8f67': 'th minut goal give iran second…',
#  '5b34bc3b54127b2bacba9719': 'portug spain poresp @ fisht olymp stadium',
#  '5b34bc3c54127b2bacba9cea': 'prost poresp : portug : : spain : wm worldcup fernprost : clinking_beer_mug : beertweet - drink sagr branca @ cervejasagr @ h…',
#  '5b34bc3c54127b2bacba9cf3': 'finish cycl km hm endomondo endorphin',
#  '5b34bc3c54127b2bacbaa153': 'wm fully…',
#  '5b34bc3c54127b2bacbaa631': 'fan iran sportphotography…',
#  '5b34bc3d54127b2bacbaa7ce': ': portug : : soccer_bal : ️ : spain : worldcup porspa ( @ grizzli bar saint petersburg st-petersburg )',
#  '5b34bc3d54127b2bacbaa826': 'jess elli lingard : england : russia vsco…',
#  '5b34bc3d54127b2bacbaa8a2': 'tweet impact португалияиспания trend wa publish @ sportsru',
#  '5b34bc3d54127b2bacbaadcd': 'worldcup - dimamaghreb morocco vs allforteammelli iran goal bouhaddouz ( goal ) at…',
#  '5b34bc3d54127b2bacbab372': 'peitch da ( dont…',
#  '5b34bc3d54127b2bacbab539': 'night rememb mobarak iran bachehaa…',
#  '5b34bc3d54127b2bacbab5ef': '@ chachagq saint petersburg st-petersburg',
#  '5b34bc3d54127b2bacbab640': 'shade saintpetersburg randomphoto @ …',
#  '5b34bc3d54127b2bacbab8f2': 'shade saintpetersburg @ saint petersburg…',
#  '5b34bc3e54127b2bacbac0f3': 'everybodi heard bird vscocam spb…',
#  '5b34bc3f54127b2bacbaca55': 'church savior…',
#  '5b34bc3f54127b2bacbaca78': 'post photo…',
#  '5b34bc3f54127b2bacbacbbb': 'post photo…',
#  '5b34bc3f54127b2bacbacc15': 'мокро @ yea park',
#  '5b34bc3f54127b2bacbad435': 'arni club saint petersburg st-petersburg',
#  '5b34bc3f54127b2bacbad844': ': vietnam : : iran : @ saint…',
#  '5b34bc3f54127b2bacbad902': 'portug - spain @ fisht olymp stadium',
#  '5b34bc4054127b2bacbadb8a': 'good day give happi bad day give…',
#  '5b34bc4054127b2bacbadbb5': 'world cup saudi arabia fa vow punish player - defeat russia',
#  '5b34bc4054127b2bacbaddcf': 'walk the…',
#  ...}

# %%
def lemmatiz(chaine):
    lemma = WordNetLemmatizer()
    lem = []
    lem2 = chaine.split(" ")
    for e in lem2:
        lem.append(lemma.lemmatize(e))
        
    return lem

# %%
#nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
stemmer_en=nltk.stem.SnowballStemmer('english')
stemmer_fr=nltk.stem.SnowballStemmer('french')
stemmer_es=nltk.stem.SnowballStemmer('spanish')
stemmer_ru=nltk.stem.SnowballStemmer('russian')

# %%
def delete_stw(liste,liste_stw):
    for e in liste:
        if e in liste_stw:
            liste.remove(e)
    return liste

# %%
stw_en=stopwords.words('english')
stw_fr=stopwords.words('french')
stw_es=stopwords.words('spanish')
stw_ru=stopwords.words('russian')
for letter in range(97,123):
    stw_en.append(chr(letter))
    stw_es.append(chr(letter))
    stw_fr.append(chr(letter))

# %%
def stem_tweet(liste,stemmer):
    return_list = []
    for e in liste:
        e2 = emoji.demojize(e)
        return_list.append(stemmer.stem(e2))
    return return_list

# %%
# Out:
# ['standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  "i'm at fifa 2018 fan fest zone saint-petersburg https://t.co/fguy4krkvk",
#  'welcome world cup russia 2018\n\ngroup a\n\nmatch… https://t.co/igda2mtxva',
#  'got to fly to russia for the 2018 world cup and hope i am finding you there too and we support our african teams. https://t.co/33cyxanerg',
#  'god bless morocco !! :morocco::morocco::morocco:\n#football #worldcup… https://t.co/qwdso6uoju',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/yckhmh8iol',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/ccwwqxnxy6',
#  'putin lad. :face_with_tears_of_joy::rolling_on_the_floor_laughing: #russia2018worldcup',
#  'first game of world cup 2018! russia :russia: and… https://t.co/0lv95zhyb',
#  'and now,\xa0let the games begin! happy world cup,… https://t.co/uo6jytmsn2',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  "i'm at fifa 2018 fan fest zone saint-petersburg https://t.co/fguy4krkvk",
#  'welcome world cup russia 2018\n\ngroup a\n\nmatch… https://t.co/igda2mtxva',
#  'got to fly to russia for the 2018 world cup and hope i am finding you there too and we support our african teams. https://t.co/33cyxanerg',
#  'god bless morocco !! :morocco::morocco::morocco:\n#football #worldcup… https://t.co/qwdso6uoju',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/yckhmh8iol',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/ccwwqxnxy6',
#  'putin lad. :face_with_tears_of_joy::rolling_on_the_floor_laughing: #russia2018worldcup',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  "i'm at fifa 2018 fan fest zone saint-petersburg https://t.co/fguy4krkvk",
#  'welcome world cup russia 2018\n\ngroup a\n\nmatch… https://t.co/igda2mtxva',
#  'got to fly to russia for the 2018 world cup and hope i am finding you there too and we support our african teams. https://t.co/33cyxanerg',
#  'god bless morocco !! :morocco::morocco::morocco:\n#football #worldcup… https://t.co/qwdso6uoju',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/yckhmh8iol',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/ccwwqxnxy6',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  "i'm at fifa 2018 fan fest zone saint-petersburg https://t.co/fguy4krkvk",
#  'welcome world cup russia 2018\n\ngroup a\n\nmatch… https://t.co/igda2mtxva',
#  'got to fly to russia for the 2018 world cup and hope i am finding you there too and we support our african teams. https://t.co/33cyxanerg',
#  'god bless morocco !! :morocco::morocco::morocco:\n#football #worldcup… https://t.co/qwdso6uoju',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/yckhmh8iol',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  "i'm at fifa 2018 fan fest zone saint-petersburg https://t.co/fguy4krkvk",
#  'welcome world cup russia 2018\n\ngroup a\n\nmatch… https://t.co/igda2mtxva',
#  'got to fly to russia for the 2018 world cup and hope i am finding you there too and we support our african teams. https://t.co/33cyxanerg',
#  'god bless morocco !! :morocco::morocco::morocco:\n#football #worldcup… https://t.co/qwdso6uoju',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/yckhmh8iol',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  "i'm at fifa 2018 fan fest zone saint-petersburg https://t.co/fguy4krkvk",
#  'welcome world cup russia 2018\n\ngroup a\n\nmatch… https://t.co/igda2mtxva',
#  'got to fly to russia for the 2018 world cup and hope i am finding you there too and we support our african teams. https://t.co/33cyxanerg',
#  'god bless morocco !! :morocco::morocco::morocco:\n#football #worldcup… https://t.co/qwdso6uoju',
#  'today is the day:clapping_hands:world cup russia 2018. our… https://t.co/yckhmh8iol',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  "i'm at fifa 2018 fan fest zone saint-petersburg https://t.co/fguy4krkvk",
#  'welcome world cup russia 2018\n\ngroup a\n\nmatch… https://t.co/igda2mtxva',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  "i'm at fifa 2018 fan fest zone saint-petersburg https://t.co/fguy4krkvk",
#  'welcome world cup russia 2018\n\ngroup a\n\nmatch… https://t.co/igda2mtxva',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#  'world cup 2018! cocaine, marijuana &amp; heroin are allowed in russia (details) https://t.co/bvbpiktpab',
#  'world cup 2018: russia welcomes the world',
#  'catching up with my… https://t.co/3kyes4m22l',
#  'i share this tbt in… https://t.co/pgp21krrmg',
#  '20k+ #google searches 4 world cup 2018 schedule 4h old https://t.co/1adhx2dzni https://t.co/iwuagmplvr #russia https://t.co/nzlobbvj1k',
#  '#worldcup2018 #zabivaka #spb @ victory square,… https://t.co/yrtkhhgruo',
#  'in st. petersburg they named a bar after the… https://t.co/q73gvla5el',
#  '#футбол @ europe/moscow https://t.co/tg6ri04oc9',
#  'so long st. petersburg. you were grand. now for… https://t.co/upfqa02mhi',
#  'throwback #throwbackthursday #russia sede del… https://t.co/ypygtjml8d',
#  'seeing romeo and juliet at one of the oldest… https://t.co/0pbjsdmz37',
#  'just posted a video @ luzhniki stadium https://t.co/gyu879nkzc',
#  '2018 fifa world cup\xa0russia https://t.co/qiysbzy6df https://t.co/3nasjyldwk',
#  'just posted a photo @ luzhniki stadium https://t.co/hgscnapqmt',
#  'from our presentation of #wip #nocturne… https://t.co/ehablsjqqu',
#  '-fifa world cup russia 2018… https://t.co/tumkhtqvzm',
#  'standing up @ saint petersburg, russia https://t.co/u9y7anqw9v',
#  'the activist kiril kotov was arrested for 15 days for picketing against world cup 2018 https://t.co/77mvunskri via… https://t.co/dfkwekquga',
#  'qajar woman of mid-1800s, not your average… https://t.co/tcuampm1wl',
#  'with nuha at world cup russia 2018 — https://t.co/w80mkmod5x',
#  'blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrn',
#   'resentment',
#   'fury',
#   'hate',
#   'anger',
#   'rancor',
#   'revenge',
#   'fury',
#   'ire',
#   'wrath',
#   'frustration',
#   'pride',
#   'despite',
#   'exasperation',
#   'furious',
#   'annoyance',
#   'revolt',
#   'fury',
#   'enmity',
#   'contempt',
#   'rancor',
#   'despondency',
#   'angry',
#   'disgust',
#   'irascibility',
#   'expletive',
#   'bitterness',
#   'aggression',
#   'impatience',
#   'threat',
#   'animosity',
#   'explosion',
#   'humiliation',
#   'violence',
#   'anger',
#   'desperation',
#   'violent',
#   'blast',
#   'avenge',
#   'stumbles',
#   'amazement',
#   'aggression',
#   'manifesting',
#   'guilt',
#   'lock',
#   'elimination',
#   'injustice',
#   'irascible',
#   'chastise',
#   'madness',
#   'dejure',
#   'incite',
#   'excite',
#   'thunder',
#   'fulminant',
#   'irritate',
#   'master',
#   'shit',
#   'deaf',
#   'rager',
#   'affront',
#   'annoyance',
#   'bubble',
#   'seizure',
#   'unleashing',
#   'irritability',
#   'irritant',
#   'outraged',
#   'repressed',
#   'vehement',
#   'acceptance',
#   'disarm',
#   'spill',
#   'pour',
#   'out',
#   'howl',
#   'impulse',
#   'indignation',
#   'exit',
#   'terrible',
#   'hostility',
#   'avenger',
#   'beating',
#   'dishonesty',
#   'end',
#   'disgrace',
#   'evil',
#   'fear',
#   'insulted',
#   'insulting',
#   'offense',
#   'overt',
#   'punish',
#   'outrage',
#   'sin',
#   'sting',
#   'greed',
#   'burning',
#   'anger',
#   'bewilderment',
#   'erupting',
#   'fever',
#   'quivering',
#   'frenzy',
#   'harassment',
#   'intemperance',
#   'intensity',
#   'interjection',
#   'malevolence',
#   'club',
#   'threatening',
#   'firecracker',
#   'provoked',
#   'spiteful',
#   'tension',
#   'violent',
#   'snarling',
#   'threatening',
#   'punk',
#   'assault',
#   'combative',
#   'hateful',
#   'provocative',
#   'aggressively',
#   'hostile',
#   'conqueror',
#   'haughty',
#   'insolent',
#   'intolerant',
#   'intruder',
#   'tone',
#   'passive',
#   'sarcastic',
#   'brutal',
#   'adversary',
#   'temperament',
#   'pitbull',
#   'bellicose',
#   'nagging',
#   'catchy',
#   'acerbic',
#   'eager',
#   'sour',
#   'brawler',
#   'battler',
#   'angry',
#   'belligerent',
#   'beatificer',
#   'quarrelsome',
#   'contentious',
#   'cruel',
#   'dangerous',
#   'dangerous',
#   'fight',
#   'fighter',
#   'frustrated',
#   'furious',
#   'irate',
#   'insecure',
#   'impetuous',
#   'irascible',
#   'malicious',
#   'martial',
#   'offending',
#   'offensive',
#   'provoking',
#   'pugnacious',
#   'raging'],
#  'hope': ['🙏forgive',
#   'pray',
#   'optimistic',
#   'positivity',
#   'positive',
#   'confidence',
#   'future',
#   'recklessness',
#   'idealism',
#   'realism',
#   'happiness',
#   'joy',
#   'intelligence',
#   'vitality',
#   'progress',
#   'calm',
#   'confident',
#   'believe',
#   'dynamic',
#   'caring',
#   'perseverance',
#   'comfortable',
#   'relaxation',
#   'euphoria',
#   'optimum',
#   'option',
#   'possible',
#   'relief',
#   'forgetfulness',
#   'abstraction',
#   'relax',
#   'want',
#   'hope',
#   'power',
#   'success',
#   'opportunity',
#   'future',
#   'innovation',
#   'perfect',
#   'confident',
#   'enthusiastic',
#   'ambition',
#   'mad',
#   'vain',
#   'wait',
#   'release',
#   'glow',
#   'courage',
#   'best',
#   'victory',
#   'desire',
#   'give',
#   'wish',
#   'return',
#   'last',
#   'time',
#   'resigned',
#   'disillusionment',
#   'concerns',
#   'reborn',
#   'dreams',
#   'faith',
#   'injury',
#   'perspective',
#   'podium',
#   'talent',
#   'purpose',
#   'confidence',
#   'healing',
#   'give',
#   'season',
#   'decisive',
#   'selected',
#   'luck',
#   'caress',
#   'conciliation',
#   'keeper',
#   'unwavering',
#   'find',
#   'save',
#   'time',
#   'life',
#   'winning',
#   'resurrect',
#   'aspiration',
#   'assurance',
#   'consolation',
#   'belief',
#   'creed',
#   'time',
#   'delivery',
#   'flattering',
#   'pause',
#   'forecast',
#   'next',
#   'project',
#   'promise',
#   'expectation',
#   'illusion',
#   'pandora',
#   'life',
#   'mercy',
#   'promise',
#   'probability',
#   'certainty',
#   'desire',
#   'gain',
#   'flag',
#   'god',
#   'light',
#   'vain',
#   'progress',
#   'belief',
#   'lure',
#   'omen',
#   'presumption',
#   'grief',
#   'enthusiasm',
#   'patient',
#   'consolation',
#   'fullness',
#   'insurance',
#   'consoling',
#   'commitment',
#   'reliability',
#   'infant',
#   'intuition',
#   'forecast',
#   'project',
#   'feeling',
#   'safety',
#   'wishes',
#   'bless',
#   'fans',
#   'ahead'],
#  'joy': ['😀',
#   '😁',
#   '😃',
#   '😝',
#   '😂',
#   '🤣',
#   '😊',
#   '👍',
#   '🏆',
#   'joy',
#   'standing',
#   'happiness',
#   'jubilation',
#   'cheerfulness',
#   'euphoria',
#   'rejoicing',
#   'serenity',
#   'bliss',
#   'joyfulness',
#   'exaltation',
#   'gaiety',
#   'joyful',
#   'delight',
#   'ineffable',
#   'radiant',
#   'voluptuousness',
#   'laugh',
#   'laughing',
#   'carried',
#   'hallelujah',
#   'kindness',
#   'delight',
#   'euphoric',
#   'exultation',
#   'feast',
#   'hilarity',
#   'enjoyment',
#   'cheer',
#   'joyous',
#   'applause',
#   'exult',
#   'maternity',
#   'baby',
#   'paternity',
#   'beaming',
#   'skip',
#   'buddy',
#   'friend',
#   'clamor',
#   'hold',
#   'elan',
#   'wonder',
#   'filled',
#   'frolicking',
#   'happy',
#   'peace',
#   'fullness',
#   'comfort',
#   'fills',
#   'sharing',
#   'celebration',
#   'success',
#   'heaven',
#   'blooming',
#   'enlightenment',
#   'freedom',
#   'fun',
#   'dancing',
#   'relaxation',
#   'distraction',
#   'entertainment',
#   'playfulness',
#   'fun',
#   'joviality',
#   'joyfulness',
#   'play',
#   'holiday',
#   'joke',
#   'fun',
#   'laugh',
#   'buzz',
#   'synthesizer',
#   'sing',
#   'travel',
#   'fairy',
#   'clap',
#   'victory',
#   'share',
#   'zabivaka',
#   'win',
#   'game',
#   'fest',
#   'playing',
#   'madness',
#   'phenomenal',
#   'thankful',
#   'happy',
#   'celebrate',
#   'cup',
#   'bar',
#   'win'],
#  'joy/hope': '',
#  'love': ["😍'",
#   '❤️',
#   '💘',
#   '💕',
#   '😘',
#   '😗',
#   'remarkable',
#   'friendship',
#   'teammate',
#   'affection',
#   'passion',
#   'love',
#   'kiss',
#   'commitment',
#   'beauty',
#   'compassion',
#   'attraction',
#   'happiness',
#   'pleasure',
#   'heart',
#   'romantic',
#   'worship',
#   'singing',
#   'fraternal',
#   'heartfelt',
#   'devotion',
#   'god',
#   'fidelity',
#   'flame',
#   'altruism',
#   'soul',
#   'sorrow',
#   'song',
#   'wife',
#   'husband',
#   'affair',
#   'loyalty',
#   'sacrifice',
#   'friendly',
#   'juliet',
#   'ideal',
#   'friends',
#   'amor',
#   'hug',
#   'girl',
#   'madly',
#   'mother',
#   'mum',
#   'admiration',
#   'generosity',
#   'respect',
#   'statement',
#   'fervor',
#   'infinite',
#   'beautiful',
#   'son',
#   'adorable',
#   'dedication',
#   'consumer',
#   'fusion',
#   'sister',
#   'ange',
#   'express',
#   'child',
#   'exaltation',
#   'wonderful',
#   'unite',
#   'madly',
#   'passion',
#   'mutual',
#   'passion',
#   'frenzy',
#   'delirium',
#   'passion',
#   'spectacular',
#   'addiction',
#   'hobbies',
#   'enthusiasm',
#   'emotion',
#   'inclination',
#   'fire',
#   'romantic',
#   'magnificent',
#   'excess',
#   'fire',
#   'mystery',
#   'passion',
#   'photography',
#   'poetry',
#   'enthusiastic',
#   'flame',
#   'sensual',
#   'delusion',
#   'crush',
#   'spirit',
#   'enthusiasm',
#   'insatiable',
#   'leisure',
#   'nativity',
#   'relationship',
#   'gardening',
#   'dedication',
#   'warmth',
#   'exalted',
#   'fury',
#   'youth',
#   'sensual',
#   'fiery',
#   'heart',
#   'wild',
#   'devotion',
#   'exhilarating',
#   'female',
#   'flatter',
#   'frantic',
#   'shameful',
#   'business',
#   'budding',
#   'meet',
#   'spend',
#   'destructive',
#   'unconsciousness',
#   'sublime',
#   'bigotry',
#   'love',
#   'soul',
#   'appetite',
#   'burning',
#   'flesh',
#   'consume',
#   'devour',
#   'player',
#   'sudden',
#   'life',
#   'choral',
#   'conviction',
#   'passion',
#   'desire',
#   'instinct',
#   'hobby',
#   'sentimental',
#   'talented',
#   'bright',
#   'collect',
#   'daydreaming',
#   'fanatical',
#   'adoration',
#   'affection',
#   'panic',
#   'agitation',
#   'overflow',
#   'momentum',
#   'excitement',
#   'enthusiasm',
#   'ecstasy',
#   'fever',
#   'obstinacy',
#   ''],
#  'love/sadness': '',
#  'neutral': '',
#  'sadness': ['💧',
#   '😿',
#   '🙀',
#   '😫',
#   '😨',
#   '😲',
#   '😞',
#   '😩',
#   '😢',
#   '😪',
#   '😷',
#   '😭',
#   '💔',
#   '😦',
#   'sadness',
#   'trouble',
#   'goodbye',
#   'melancholy',
#   'grief',
#   'mourning',
#   'despair',
#   'nostalgia',
#   'disgust',
#   'pain',
#   'tear',
#   'sad',
#   'bitterness',
#   'discouragement',
#   'loneliness',
#   'sadness',
#   'melancholy',
#   'depression',
#   'affliction',
#   'lassitude',
#   'desolation',
#   'misfortune',
#   'languor',
#   'resignation',
#   'cockroach',
#   'despondency',
#   'regret',
#   'crying',
#   'bitter',
#   'worry',
#   'compassion',
#   'consolation',
#   'rancor',
#   'spree',
#   'deep',
#   'acedial',
#   'blues',
#   'glaucous',
#   'farewell',
#   'tearing',
#   'despite',
#   'disgust',
#   'overwhelmed',
#   'shot',
#   'lament',
#   'gloomy',
#   'cloud',
#   'aggression',
#   'anguish',
#   'boredom',
#   'disappointment',
#   'despair',
#   'disgruntled',
#   'displeasure',
#   'fatigue',
#   'frustration',
#   'gloomy',
#   'grief',
#   'loneliness',
#   'miserable',
#   'unhappiness',
#   'painful',
#   'despair',
#   'collapsed',
#   'inconsolable',
#   'indefinable',
#   'evil',
#   'misanthropy',
#   'misery',
#   'poverty',
#   'laziness',
#   'isolation',
#   'malaise',
#   'moral',
#   'rancor',
#   'despondency',
#   'sadness',
#   'boredom',
#   'dreadfulness',
#   'dreariness',
#   'embarrassment',
#   'festering',
#   'greed',
#   'hypochondria',
#   'unspeakable',
#   'dreary',
#   'monotonous',
#   'recollection',
#   'stunner',
#   'torment',
#   'uniformity',
#   'suicide',
#   'poor',
#   'homeless',
#   'cemetery',
#   'creeping',
#   'grievousness',
#   'grievous',
#   'old',
#   'age',
#   'shabby',
#   'pity',
#   'pessimistic',
#   'pessimism',
#   'will',
#   'defeatism',
#   'melancholy',
#   'skepticism',
#   'bitter',
#   'morbid',
#   'philosophical',
#   'resignation',
#   'subjective',
#   'bitterness',
#   'disgust',
#   'fatalism',
#   'romanticism',
#   'symbolism',
#   'conception',
#   'romantic',
#   'suicide',
#   'individualism',
#   'denouement',
#   'renunciation',
#   'negative',
#   'decadence',
#   'alarmism',
#   'catastrophism',
#   'disbelief',
#   'disquiet',
#   'neurasthenia',
#   'nostalgia',
#   'worry',
#   'tracassin',
#   'tragic',
#   'misery',
#   'unemployment',
#   'suicide',
#   'poor',
#   'dead',
#   'death',
#   'cemetery',
#   'tears',
#   'injustice',
#   'shabby',
#   'pitiful',
#   'pity',
#   'sick',
#   'lose']}

# %%
#Input: Dictionnaire de champ lexicaux à stemmatiser. 
#Output: Dictionnaire dict_sentiment_stem ou l'on a pris la racine des mots de dict_sentiment
def stem_lexical(dic,stemmer):  
    dict_sentiment_stem = {"joy":"","hope":"","love":"","sadness":"","anger":"","neutral":"","joy/hope":"","love/sadness":""}
    for keys in dic:
        liste = []
        for values in dic[keys]:
            values2 = emoji.demojize(values)
            liste.append(stemmer.stem(values2))
        dict_sentiment_stem[keys] = set(liste)
    return dict_sentiment_stem

# %%
dict_sentiment_en_stem=stem_lexical(dict_sentiment_en,stemmer_en)
dict_sentiment_ru_stem=stem_lexical(dict_sentiment_ru,stemmer_ru)

# %%
dict_sentiment_en_stem
# Out:
# {'anger': {':anger_symbol:',
#   ':angry_face:',
#   ':exclamation_mark:',
#   ':face_with_steam_from_nose:',
#   ':middle_finger:',
#   ':oncoming_fist:',
#   ':pouting_face:',
#   ':red_circle:',
#   ':skull:',
#   ':thumbs_down:',
#   ':unamused_face:',
#   'accept',
#   'acerb',
#   'adversari',
#   'affront',
#   'aggress',
#   'amaz',
#   'anger',
#   'angri',
#   'animos',
#   'annoy',
#   'assault',
#   'aveng',
#   'battler',
#   'beat',
#   'beatific',
#   'bellicos',
#   'belliger',
#   'bewilder',
#   'bitter',
#   'blast',
#   'brawler',
#   'brutal',
#   'bubbl',
#   'burn',
#   'catchi',
#   'chastis',
#   'choler',
#   'club',
#   'combat',
#   'conqueror',
#   'contempt',
#   'contenti',
#   'cruel',
#   'cuss',
#   'danger',
#   'deaf',
#   'dejur',
#   'desper',
#   'despit',
#   'despond',
#   'disarm',
#   'disgrac',
#   'disgust',
#   'dishonesti',
#   'eager',
#   'elimin',
#   'end',
#   'enmiti',
#   'erupt',
#   'evil',
#   'exasper',
#   'excit',
#   'exit',
#   'explet',
#   'explos',
#   'fear',
#   'fever',
#   'fight',
#   'fighter',
#   'firecrack',
#   'frenzi',
#   'frustrat',
#   'fulmin',
#   'furi',
#   'furious',
#   'fuss',
#   'greed',
#   'guilt',
#   'harass',
#   'hate',
#   'haughti',
#   'hostil',
#   'howl',
#   'humili',
#   'impati',
#   'impetu',
#   'impuls',
#   'incit',
#   'indign',
#   'injustic',
#   'insecur',
#   'insol',
#   'insult',
#   'intemper',
#   'intens',
#   'interject',
#   'intoler',
#   'intrud',
#   'irasc',
#   'irat',
#   'ire',
#   'irrit',
#   'lock',
#   'mad',
#   'malevol',
#   'malici',
#   'manifest',
#   'martial',
#   'master',
#   'nag',
#   'offend',
#   'offens',
#   'out',
#   'outrag',
#   'overt',
#   'passiv',
#   'pitbul',
#   'pour',
#   'pride',
#   'provoc',
#   'provok',
#   'pugnaci',
#   'punish',
#   'punk',
#   'quarrelsom',
#   'quiver',
#   'rage',
#   'rager',
#   'rancor',
#   'repress',
#   'resent',
#   'reveng',
#   'revolt',
#   'sarcast',
#   'seizur',
#   'shit',
#   'sin',
#   'skull',
#   'snarl',
#   'sour',
#   'spill',
#   'spite',
#   'sting',
#   'stumbl',
#   'tempera',
#   'tension',
#   'terribl',
#   'threat',
#   'threaten',
#   'thunder',
#   'tone',
#   'unleash',
#   'vehement',
#   'violenc',
#   'violent',
#   'wrath'},
#  'hope': {':folded_hands:forg',
#   'abstract',
#   'ahead',
#   'ambit',
#   'aspir',
#   'assur',
#   'belief',
#   'believ',
#   'best',
#   'bless',
#   'calm',
#   'care',
#   'caress',
#   'certainti',
#   'comfort',
#   'commit',
#   'concern',
#   'concili',
#   'confid',
#   'consol',
#   'courag',
#   'creed',
#   'decis',
#   'deliveri',
#   'desir',
#   'disillusion',
#   'dream',
#   'dynam',
#   'enthusiasm',
#   'enthusiast',
#   'euphoria',
#   'expect',
#   'faith',
#   'fan',
#   'feel',
#   'find',
#   'flag',
#   'flatter',
#   'forecast',
#   'forget',
#   'full',
#   'futur',
#   'gain',
#   'give',
#   'glow',
#   'god',
#   'grief',
#   'happi',
#   'heal',
#   'hope',
#   'ideal',
#   'illus',
#   'infant',
#   'injuri',
#   'innov',
#   'insur',
#   'intellig',
#   'intuit',
#   'joy',
#   'keeper',
#   'last',
#   'life',
#   'light',
#   'luck',
#   'lure',
#   'mad',
#   'merci',
#   'next',
#   'omen',
#   'opportun',
#   'optimist',
#   'optimum',
#   'option',
#   'pandora',
#   'patient',
#   'paus',
#   'perfect',
#   'persever',
#   'perspect',
#   'podium',
#   'posit',
#   'possibl',
#   'power',
#   'pray',
#   'presumpt',
#   'probabl',
#   'progress',
#   'project',
#   'promis',
#   'purpos',
#   'realism',
#   'reborn',
#   'reckless',
#   'relax',
#   'releas',
#   'reliabl',
#   'relief',
#   'resign',
#   'resurrect',
#   'return',
#   'safeti',
#   'save',
#   'season',
#   'select',
#   'success',
#   'talent',
#   'time',
#   'unwav',
#   'vain',
#   'victori',
#   'vital',
#   'wait',
#   'want',
#   'win',
#   'wish'},
#  'joy': {':beaming_face_with_smiling_eyes:',
#   ':face_with_tears_of_joy:',
#   ':grinning_face:',
#   ':grinning_face_with_big_eyes:',
#   ':rolling_on_the_floor_laughing:',
#   ':smiling_face_with_smiling_eyes:',
#   ':squinting_face_with_tongue:',
#   ':thumbs_up:',
#   ':trophy:',
#   'applaus',
#   'babi',
#   'bar',
#   'beam',
#   'bliss',
#   'bloom',
#   'buddi',
#   'buzz',
#   'carri',
#   'celebr',
#   'cheer',
#   'clamor',
#   'clap',
#   'comfort',
#   'cup',
#   'danc',
#   'delight',
#   'distract',
#   'elan',
#   'enjoy',
#   'enlighten',
#   'entertain',
#   'euphor',
#   'euphoria',
#   'exalt',
#   'exult',
#   'fairi',
#   'feast',
#   'fest',
#   'fill',
#   'freedom',
#   'friend',
#   'frolick',
#   'full',
#   'fun',
#   'gaieti',
#   'game',
#   'hallelujah',
#   'happi',
#   'heaven',
#   'hilar',
#   'hold',
#   'holiday',
#   'ineff',
#   'joke',
#   'jovial',
#   'joy',
#   'joyous',
#   'jubil',
#   'kind',
#   'laugh',
#   'mad',
#   'matern',
#   'patern',
#   'peac',
#   'phenomen',
#   'play',
#   'radiant',
#   'rejoic',
#   'relax',
#   'seren',
#   'share',
#   'sing',
#   'skip',
#   'stand',
#   'success',
#   'synthes',
#   'thank',
#   'travel',
#   'victori',
#   'voluptu',
#   'win',
#   'wonder',
#   'zabivaka'},
#  'joy/hope': set(),
#  'love': {'',
#   ':face_blowing_a_kiss:',
#   ':heart_with_arrow:',
#   ':kissing_face:',
#   ':red_heart:️',
#   ':smiling_face_with_heart-eyes:',
#   ':two_hearts:',
#   'addict',
#   'admir',
#   'ador',
#   'affair',
#   'affect',
#   'agit',
#   'altruism',
#   'amor',
#   'ang',
#   'appetit',
#   'attract',
#   'beauti',
#   'bigotri',
#   'bright',
#   'bud',
#   'burn',
#   'busi',
#   'child',
#   'choral',
#   'collect',
#   'commit',
#   'compass',
#   'consum',
#   'convict',
#   'crush',
#   'daydream',
#   'dedic',
#   'delirium',
#   'delus',
#   'desir',
#   'destruct',
#   'devot',
#   'devour',
#   'ecstasi',
#   'emot',
#   'enthusiasm',
#   'enthusiast',
#   'exalt',
#   'excess',
#   'excit',
#   'exhilar',
#   'express',
#   'fanat',
#   'femal',
#   'fervor',
#   'fever',
#   'fidel',
#   'fieri',
#   'fire',
#   'flame',
#   'flatter',
#   'flesh',
#   'frantic',
#   'fratern',
#   'frenzi',
#   'friend',
#   'friendship',
#   'furi',
#   'fusion',
#   'garden',
#   'generos',
#   'girl',
#   'god',
#   'happi',
#   'heart',
#   'heartfelt',
#   'hobbi',
#   'hug',
#   'husband',
#   'ideal',
#   'inclin',
#   'infinit',
#   'insati',
#   'instinct',
#   'juliet',
#   'kiss',
#   'leisur',
#   'life',
#   'love',
#   'loyalti',
#   'mad',
#   'magnific',
#   'meet',
#   'momentum',
#   'mother',
#   'mum',
#   'mutual',
#   'mysteri',
#   'nativ',
#   'obstinaci',
#   'overflow',
#   'panic',
#   'passion',
#   'photographi',
#   'player',
#   'pleasur',
#   'poetri',
#   'relationship',
#   'remark',
#   'respect',
#   'romant',
#   'sacrific',
#   'sensual',
#   'sentiment',
#   'shame',
#   'sing',
#   'sister',
#   'son',
#   'song',
#   'sorrow',
#   'soul',
#   'spectacular',
#   'spend',
#   'spirit',
#   'statement',
#   'sublim',
#   'sudden',
#   'talent',
#   'teammat',
#   'unconsci',
#   'unit',
#   'warmth',
#   'wife',
#   'wild',
#   'wonder',
#   'worship',
#   'youth'},
#  'love/sadness': set(),
#  'neutral': set(),
#  'sadness': {':astonished_face:',
#   ':broken_heart:',
#   ':crying_cat_face:',
#   ':crying_face:',
#   ':disappointed_face:',
#   ':droplet:',
#   ':face_with_medical_mask:',
#   ':fearful_face:',
#   ':frowning_face_with_open_mouth:',
#   ':loudly_crying_face:',
#   ':sleepy_face:',
#   ':tired_face:',
#   ':weary_cat_face:',
#   ':weary_face:',
#   'acedi',
#   'afflict',
#   'age',
#   'aggress',
#   'alarm',
#   'anguish',
#   'bitter',
#   'blue',
#   'boredom',
#   'catastroph',
#   'cemeteri',
#   'cloud',
#   'cockroach',
#   'collaps',
#   'compass',
#   'concept',
#   'consol',
#   'creep',
#   'cri',
#   'dead',
#   'death',
#   'decad',
#   'deep',
#   'defeat',
#   'denouement',
#   'depress',
#   'desol',
#   'despair',
#   'despit',
#   'despond',
#   'disappoint',
#   'disbelief',
#   'discourag',
#   'disgruntl',
#   'disgust',
#   'displeasur',
#   'disquiet',
#   'dread',
#   'dreari',
#   'embarrass',
#   'evil',
#   'farewel',
#   'fatal',
#   'fatigu',
#   'fester',
#   'frustrat',
#   'glaucous',
#   'gloomi',
#   'goodby',
#   'greed',
#   'grief',
#   'grievous',
#   'homeless',
#   'hypochondria',
#   'inconsol',
#   'indefin',
#   'individu',
#   'injustic',
#   'isol',
#   'lament',
#   'languor',
#   'lassitud',
#   'lazi',
#   'loneli',
#   'lose',
#   'malais',
#   'melancholi',
#   'misanthropi',
#   'miser',
#   'miseri',
#   'misfortun',
#   'monoton',
#   'moral',
#   'morbid',
#   'mourn',
#   'negat',
#   'neurasthenia',
#   'nostalgia',
#   'old',
#   'overwhelm',
#   'pain',
#   'pessim',
#   'pessimist',
#   'philosoph',
#   'piti',
#   'poor',
#   'poverti',
#   'rancor',
#   'recollect',
#   'regret',
#   'renunci',
#   'resign',
#   'romant',
#   'romantic',
#   'sad',
#   'shabbi',
#   'shot',
#   'sick',
#   'skeptic',
#   'spree',
#   'stunner',
#   'subject',
#   'suicid',
#   'symbol',
#   'tear',
#   'torment',
#   'tracassin',
#   'tragic',
#   'troubl',
#   'unemploy',
#   'unhappi',
#   'uniform',
#   'unspeak',
#   'will',
#   'worri'}}

# %%
def length_lexical_word(lang,dico_stem):
    print("\nLongueur des champs lexicaux "+lang)
    for k in dico_stem:
        print(k+": "+str(len(dico_stem[k])))

# %%
length_lexical_word("english",dict_sentiment_en_stem)
length_lexical_word("russian",dict_sentiment_ru_stem)
# Out:
# Longueur des champs lexicaux english
# joy: 83
# hope: 115
# love: 134
# sadness: 129
# anger: 157
# neutral: 0
# joy/hope: 0
# love/sadness: 0
#
# Longueur des champs lexicaux russian
# joy: 78
# hope: 113
# love: 126
# sadness: 128
# anger: 144
# neutral: 0
# joy/hope: 0
# love/sadness: 0

# %%
def count(tweet, dic_sent):
    dico = {"joy":0,"hope":0,"love":0,"sadness":0,"anger":0,"neutral":0,"joy/hope":0,"love/sadness":0}
    for key in dico:
        for mot in tweet:
            if mot in dic_sent[key]:
                dico[key]+=1
    if (dico["joy"] == 0 and dico["hope"]  == 0 and dico["love"] == 0 and dico["sadness"] == 0 and dico["anger"]== 0 ):
        dico["neutral"] +=10
    if (dico["joy"] == dico["hope"]):
        dico["joy/hope"] = dico["joy"]+dico["hope"]
    if (dico["sadness"] == dico["love"]):
        dico["love/sadness"] = dico["love"]+dico["sadness"]
    return dico

#Input: tweet à prédire
#Output: résultat de count(tweet stemmatisée,dic,stopwords)
def predict_sentiment(tweet0, dic,stopwords,stemmer):
    a = lemmatiz(tweet0)
    liste = delete_stw(a,stopwords)
    a = stem_tweet(a,stemmer)
    return count(a,dic)

# %%
tweet_pred=list_low_en[4]
print(tweet_pred)
senti=predict_sentiment(tweet_pred, dict_sentiment_en_stem,stw_en,stemmer_en)
senti
# Out:
# blue islands of green ocean.  #skydome #skyabove… https://t.co/yg1fulmrns
# {'anger': 0,
#  'hope': 0,
#  'joy': 0,
#  'joy/hope': 0,
#  'love': 1,
#  'love/sadness': 2,
#  'neutral': 0,
#  'sadness': 1}

# %%
tweet_pred2=list_low_ru[6]
print(tweet_pred2)
senti2=predict_sentiment(tweet_pred2, dict_sentiment_ru_stem,stw_ru,stemmer_ru)
senti2
# Out:
# ну что,  погнали? 🙏❤️🏆
# .
# .
# #3часадо #чм2018… https://t.co/0abdxsk4by
# {'anger': 0,
#  'hope': 0,
#  'joy': 0,
#  'joy/hope': 0,
#  'love': 0,
#  'love/sadness': 0,
#  'neutral': 10,
#  'sadness': 0}

# %%
for i in range(0,len(list_low_en)):
    tweet_pred2=list_low_en[i]
    senti2=predict_sentiment(tweet_pred2, dict_sentiment_en_stem,stw_en,stemmer_en)
    senti2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5d6018243dfa> in <module>()
# ----> 1 for i in range(0,len(list_low_en)):
#       2     tweet_pred2=list_low_en[i]
#       3     senti2=predict_sentiment(tweet_pred2, dict_sentiment_en_stem,stw_en,stemmer_en)
#       4     senti2
#
# NameError: name 'list_low_en' is not defined

# %%
#Code test, prédit toutes les tweets dans list_low_en
#Output: Dictionnaire => sentiment : ids des tweets qui ont ce sentiment

dico_test_en = {"joy":[],"hope":[],"love":[],"sadness":[],"anger":[],"neutral":[],"joy/hope":[],"love/sadness":[]}

dico_test_ru = {"joy":[],"hope":[],"love":[],"sadness":[],"anger":[],"neutral":[],"joy/hope":[],"love/sadness":[]}

for i in range(0,len(list_low_en)):
    tweet_pred=list_low_en[i]
    senti_en=predict_sentiment(tweet_pred, dict_sentiment_en_stem,stw_en,stemmer_en)
    dico_test_en[max(senti_en.items(), key=operator.itemgetter(1))[0]].append(i)
    #Affiche pour chaque sentiment le nombre de tweets qui ont ce sentiment
for k in dico_test_en:
    print("english " +k+": "+str(len(dico_test_en[k])))

for i in range(0,len(list_low_ru)):
    tweet_pred=list_low_ru[i]
    senti_ru=predict_sentiment(tweet_pred, dict_sentiment_ru_stem,stw_ru,stemmer_ru)
    dico_test_ru[max(senti_ru.items(), key=operator.itemgetter(1))[0]].append(i)
    #Affiche pour chaque sentiment le nombre de tweets qui ont ce sentiment
for k in dico_test_ru:
    print("russian "+ k+": "+str(len(dico_test_ru[k])))
# Out:
# english joy: 644
# english hope: 142
# english love: 157
# english sadness: 17
# english anger: 24
# english neutral: 1237
# english joy/hope: 95
# english love/sadness: 49
# russian joy: 637
# russian hope: 340
# russian love: 200
# russian sadness: 123
# russian anger: 80
# russian neutral: 7459
# russian joy/hope: 113
# russian love/sadness: 5

# %%
#Affiche le tweet et le sentiment associé
i = 0
tweet_pred_en=list_low_en[i]
print(str(tweet_pred_en)+"\n")
senti_en=predict_sentiment(tweet_pred_en, dict_sentiment_en_stem,stw_en,stemmer_en)
print("principal sentiment: "+max(senti_en.items(), key=operator.itemgetter(1))[0])
print(senti_en)
print(i)
i+=1
# Out:
# standing up @ saint petersburg, russia https://t.co/u9y7anqw9v
#
# principal sentiment: joy
# {'joy': 1, 'hope': 0, 'love': 0, 'sadness': 0, 'anger': 0, 'neutral': 0, 'joy/hope': 0, 'love/sadness': 0}
# 0

# %%
list_senti_en = list()
for i in range(0,len(list_low_en)):
    tweet_pred_en=list_low_en[i]
    senti_en=predict_sentiment(tweet_pred_en, dict_sentiment_en_stem,stw_en,stemmer_en)
    list_senti_en.append(max(senti_en.items(), key=operator.itemgetter(1))[0])
    dict_id_sent_en = dict(zip(list_good_id_en,list_senti_en))

# %%
list_senti_ru = list()
for i in range(0,len(list_low_ru)):
    tweet_pred_ru=list_low_ru[i]
    senti_ru=predict_sentiment(tweet_pred_ru, dict_sentiment_ru_stem,stw_ru,stemmer_ru)
    list_senti_ru.append(max(senti_ru.items(), key=operator.itemgetter(1))[0])
    dict_id_sent_ru = dict(zip(list_good_id_ru,list_senti_ru))

# %%
dict_id_sent_en
# Out:
# {'5b30dddaa8059696856d2cc1': 'joy',
#  '5b30dddaa8059696856d2d9b': 'joy',
#  '5b30dddaa8059696856d2f66': 'neutral',
#  '5b30dddca8059696856d407c': 'joy',
#  '5b30dddca8059696856d42cc': 'love/sadness',
#  '5b30dddda8059696856d4a49': 'joy',
#  '5b30dddda8059696856d4ada': 'joy',
#  '5b30dddea8059696856d4c8c': 'neutral',
#  '5b30dddea8059696856d513d': 'joy',
#  '5b30dddfa8059696856d52ff': 'joy',
#  '5b30dddfa8059696856d5373': 'joy/hope',
#  '5b30dddfa8059696856d5763': 'joy',
#  '5b30dde0a8059696856d5db0': 'neutral',
#  '5b30dde1a8059696856d6267': 'neutral',
#  '5b30dde1a8059696856d64d8': 'neutral',
#  '5b30dde1a8059696856d6946': 'love',
#  '5b30dde2a8059696856d6c49': 'neutral',
#  '5b30dde2a8059696856d712b': 'neutral',
#  '5b30dde3a8059696856d76e6': 'neutral',
#  '5b30dde5a8059696856d8434': 'neutral',
#  '5b30e3c8dbf70ad71b268092': 'joy',
#  '5b30e3c8dbf70ad71b26816c': 'joy',
#  '5b30e3c8dbf70ad71b268337': 'neutral',
#  '5b30e3df81f81adef24250d5': 'joy',
#  '5b30e3df81f81adef24251af': 'joy',
#  '5b30e3df81f81adef242537a': 'neutral',
#  '5b30e3e181f81adef2426490': 'joy',
#  '5b30e3e181f81adef24266e0': 'love/sadness',
#  '5b30e3e281f81adef2426e5d': 'joy',
#  '5b30e3e281f81adef2426eee': 'joy',
#  '5b30e3e381f81adef24270a0': 'neutral',
#  '5b30e3e381f81adef2427551': 'joy',
#  '5b30e3e481f81adef2427713': 'joy',
#  '5b30e3e481f81adef2427787': 'joy/hope',
#  '5b30e3e481f81adef2427b77': 'joy',
#  '5b30e3e581f81adef24281c4': 'neutral',
#  '5b30e3e581f81adef242867b': 'neutral',
#  '5b30e3e581f81adef24288ec': 'neutral',
#  '5b30e3e681f81adef2428d5a': 'love',
#  '5b30e3e681f81adef242905d': 'neutral',
#  '5b30e3e781f81adef242953f': 'neutral',
#  '5b30e3e881f81adef2429afa': 'neutral',
#  '5b30e4bca076c81194cb4827': 'joy',
#  '5b30e4bca076c81194cb4901': 'joy',
#  '5b30e4bca076c81194cb4acc': 'neutral',
#  '5b30e4bfa076c81194cb5be2': 'joy',
#  '5b30e4bfa076c81194cb5e32': 'love/sadness',
#  '5b30ecacdeff1914f84963f1': 'joy',
#  '5b30ecacdeff1914f84964cb': 'joy',
#  '5b30ecacdeff1914f8496696': 'neutral',
#  '5b30ecafdeff1914f84977ac': 'joy',
#  '5b30ecafdeff1914f84979fc': 'love/sadness',
#  '5b30ecb0deff1914f8498179': 'joy',
#  '5b30ecb0deff1914f849820a': 'joy',
#  '5b30ecb0deff1914f84983bc': 'neutral',
#  '5b30ecb1deff1914f849886d': 'joy',
#  '5b30ecb1deff1914f8498a2f': 'joy',
#  '5b30ecb1deff1914f8498aa3': 'joy/hope',
#  '5b30ecb2deff1914f8498e93': 'joy',
#  '5b30ecb2deff1914f84994e0': 'neutral',
#  '5b30ecb3deff1914f8499997': 'neutral',
#  '5b30ecb3deff1914f8499c08': 'neutral',
#  '5b30ecb4deff1914f849a076': 'love',
#  '5b30ecb4deff1914f849a379': 'neutral',
#  '5b30ecb5deff1914f849a85b': 'neutral',
#  '5b30ecb6deff1914f849ae16': 'neutral',
#  '5b30ecb8deff1914f849bb64': 'neutral',
#  '5b30f08b5970d8fd15e7d978': 'joy',
#  '5b30f08c5970d8fd15e7da52': 'joy',
#  '5b30f08c5970d8fd15e7dc1d': 'neutral',
#  '5b30f08e5970d8fd15e7ed33': 'joy',
#  '5b30f08f5970d8fd15e7ef83': 'love/sadness',
#  '5b30f0905970d8fd15e7f700': 'joy',
#  '5b30f0905970d8fd15e7f791': 'joy',
#  '5b30f0905970d8fd15e7f943': 'neutral',
#  '5b30f0915970d8fd15e7fdf4': 'joy',
#  '5b30f0915970d8fd15e7ffb6': 'joy',
#  '5b30f0915970d8fd15e8002a': 'joy/hope',
#  '5b30f0925970d8fd15e8041a': 'joy',
#  '5b30f0935970d8fd15e80a67': 'neutral',
#  '5b30f0945970d8fd15e80f1e': 'neutral',
#  '5b30f0945970d8fd15e8118f': 'neutral',
#  '5b30f0955970d8fd15e815fd': 'love',
#  '5b30f0955970d8fd15e81900': 'neutral',
#  '5b30f0965970d8fd15e81de2': 'neutral',
#  '5b30f0975970d8fd15e8239d': 'neutral',
#  '5b30f0995970d8fd15e830eb': 'neutral',
#  '5b30f09c5970d8fd15e83ff7': 'joy',
#  '5b30f09f5970d8fd15e84fa7': 'joy/hope',
#  '5b30f09f5970d8fd15e851e7': 'joy',
#  '5b30f09f5970d8fd15e85568': 'hope',
#  '5b30f0a05970d8fd15e85819': 'hope',
#  '5b30f0a15970d8fd15e85f3f': 'joy',
#  '5b30f0a35970d8fd15e8705d': 'joy',
#  '5b30f0a45970d8fd15e87bc6': 'neutral',
#  '5b30f0a55970d8fd15e88335': 'joy',
#  '5b30f0a65970d8fd15e886a1': 'joy',
#  '5b30f190ffb5041f0dada590': 'joy',
#  '5b30f190ffb5041f0dada66a': 'joy',
#  '5b30f191ffb5041f0dada835': 'neutral',
#  '5b30f1aa1f31bddaea300fd3': 'joy',
#  '5b30f1aa1f31bddaea3010ad': 'joy',
#  '5b30f1aa1f31bddaea301278': 'neutral',
#  '5b30f1ad1f31bddaea30238e': 'joy',
#  '5b30f1ad1f31bddaea3025de': 'love/sadness',
#  '5b30f1ae1f31bddaea302d5b': 'joy',
#  '5b30f1ae1f31bddaea302dec': 'joy',
#  '5b30f1af1f31bddaea302f9e': 'neutral',
#  '5b30f1af1f31bddaea30344f': 'joy',
#  '5b30f1b01f31bddaea303611': 'joy',
#  '5b30f1b01f31bddaea303685': 'joy/hope',
#  '5b30f1b01f31bddaea303a75': 'joy',
#  '5b30f1b11f31bddaea3040c2': 'neutral',
#  '5b30f1b21f31bddaea304579': 'neutral',
#  '5b30f2e26823b1fcf1867d0d': 'neutral',
#  '5b30f2e36823b1fcf18681be': 'joy',
#  '5b30f2e36823b1fcf1868380': 'joy',
#  '5b30f2e36823b1fcf18683f4': 'joy/hope',
#  '5b30f2e46823b1fcf18687e4': 'joy',
#  '5b30f2e56823b1fcf1868e31': 'neutral',
#  '5b30f2e56823b1fcf18692e8': 'neutral',
#  '5b30f2e66823b1fcf1869559': 'neutral',
#  '5b30f2e76823b1fcf18699c7': 'love',
#  '5b30f2e76823b1fcf1869cca': 'neutral',
#  '5b30f2e86823b1fcf186a1ac': 'neutral',
#  '5b30f2e96823b1fcf186a767': 'neutral',
#  '5b30f2f46823b1fcf186b4b5': 'neutral',
#  '5b30f3006823b1fcf186c3c1': 'joy',
#  '5b30f30d6823b1fcf186d371': 'joy/hope',
#  '5b30f30f6823b1fcf186d5b1': 'joy',
#  '5b30f3116823b1fcf186d932': 'hope',
#  '5b30f3136823b1fcf186dbe3': 'hope',
#  '5b30f3176823b1fcf186e309': 'joy',
#  '5b30f3ae22198c8439eadc71': 'joy',
#  '5b30f3af22198c8439eadd4b': 'joy',
#  '5b30f3af22198c8439eadf16': 'neutral',
#  '5b30f3b222198c8439eaf02c': 'joy',
#  '5b30f3b222198c8439eaf27c': 'love/sadness',
#  '5b30f3b422198c8439eaf9f9': 'joy',
#  '5b30f3b422198c8439eafa8a': 'joy',
#  '5b30f3c3d85e36841fb6a441': 'joy',
#  '5b30f3c3d85e36841fb6a51b': 'joy',
#  '5b30f3c4d85e36841fb6a6e6': 'neutral',
#  '5b30f3c6d85e36841fb6b7fc': 'joy',
#  '5b30f3c7d85e36841fb6ba4c': 'love/sadness',
#  '5b30f3c8d85e36841fb6c1c9': 'joy',
#  '5b30f3c8d85e36841fb6c25a': 'joy',
#  '5b30f3c8d85e36841fb6c40c': 'neutral',
#  '5b30f3c9d85e36841fb6c8bd': 'joy',
#  '5b30f3c9d85e36841fb6ca7f': 'joy',
#  '5b30f3c9d85e36841fb6caf3': 'joy/hope',
#  '5b30f3cad85e36841fb6cee3': 'joy',
#  '5b30f3cbd85e36841fb6d530': 'neutral',
#  '5b30f3ccd85e36841fb6d9e7': 'neutral',
#  '5b30f3ccd85e36841fb6dc58': 'neutral',
#  '5b30f3cdd85e36841fb6e0c6': 'love',
#  '5b30f3cdd85e36841fb6e3c9': 'neutral',
#  '5b30f3ced85e36841fb6e8ab': 'neutral',
#  '5b30f3cfd85e36841fb6ee66': 'neutral',
#  '5b30f3d1d85e36841fb6fbb4': 'neutral',
#  '5b30f3d4d85e36841fb70ac0': 'joy',
#  '5b30f3d7d85e36841fb71a70': 'joy/hope',
#  '5b30f3d7d85e36841fb71cb0': 'joy',
#  '5b30f3d7d85e36841fb72031': 'hope',
#  '5b30f3d8d85e36841fb722e2': 'hope',
#  '5b30f3d9d85e36841fb72a08': 'joy',
#  '5b30f4883862643d0c2a6799': 'joy',
#  '5b30f4883862643d0c2a6873': 'joy',
#  '5b30f4883862643d0c2a6a3e': 'neutral',
#  '5b30f66562b85ac4769f2985': 'joy',
#  '5b338c26422477dfab8e6f0e': 'joy',
#  '5b338c27422477dfab8e6fe8': 'joy',
#  '5b338c27422477dfab8e71b3': 'neutral',
#  '5b338c29422477dfab8e82c9': 'joy',
#  '5b338c2a422477dfab8e8519': 'love/sadness',
#  '5b338c2b422477dfab8e8c96': 'joy',
#  '5b338c2b422477dfab8e8d27': 'joy',
#  '5b338c2b422477dfab8e8ed9': 'neutral',
#  '5b338c2c422477dfab8e938a': 'joy',
#  '5b338c2c422477dfab8e954c': 'joy',
#  '5b338c2c422477dfab8e95c0': 'joy/hope',
#  '5b338c2d422477dfab8e99b0': 'joy',
#  '5b338c2e422477dfab8e9ffd': 'neutral',
#  '5b338c2e422477dfab8ea4b4': 'neutral',
#  '5b338c2f422477dfab8ea725': 'neutral',
#  '5b338c2f422477dfab8eab93': 'love',
#  '5b338c30422477dfab8eae96': 'neutral',
#  '5b338c31422477dfab8eb378': 'neutral',
#  '5b338c32422477dfab8eb933': 'neutral',
#  '5b338c34422477dfab8ec681': 'neutral',
#  '5b338c37422477dfab8ed58d': 'joy',
#  '5b338c39422477dfab8ee53d': 'joy/hope',
#  '5b338c39422477dfab8ee77d': 'joy',
#  '5b338ceaa5d973963e1701b1': 'joy',
#  '5b338ceaa5d973963e17028b': 'joy',
#  '5b338ceba5d973963e170456': 'neutral',
#  '5b338ceda5d973963e17156c': 'joy',
#  '5b338ceda5d973963e1717bc': 'love/sadness',
#  '5b338ceea5d973963e171f39': 'joy',
#  '5b338ceea5d973963e171fca': 'joy',
#  '5b338cefa5d973963e17217c': 'neutral',
#  '5b338cf0a5d973963e17262d': 'joy',
#  '5b338cf0a5d973963e1727ef': 'joy',
#  '5b338cf0a5d973963e172863': 'joy/hope',
#  '5b338cf0a5d973963e172c53': 'joy',
#  '5b338cf1a5d973963e1732a0': 'neutral',
#  '5b338d9018248d8b6c9609cb': 'joy',
#  '5b338d9018248d8b6c960aa5': 'joy',
#  '5b338d9118248d8b6c960c70': 'neutral',
#  '5b338d9318248d8b6c961d86': 'joy',
#  '5b338d9318248d8b6c961fd6': 'love/sadness',
#  '5b338d9518248d8b6c962753': 'joy',
#  '5b338d9518248d8b6c9627e4': 'joy',
#  '5b338d9518248d8b6c962996': 'neutral',
#  '5b338d9618248d8b6c962e47': 'joy',
#  '5b338d9618248d8b6c963009': 'joy',
#  '5b338d9618248d8b6c96307d': 'joy/hope',
#  '5b338d9718248d8b6c96346d': 'joy',
#  '5b338d9818248d8b6c963aba': 'neutral',
#  '5b338d9818248d8b6c963f71': 'neutral',
#  '5b338d9918248d8b6c9641e2': 'neutral',
#  '5b338d9918248d8b6c964650': 'love',
#  '5b338d9a18248d8b6c964953': 'neutral',
#  '5b338d9b18248d8b6c964e35': 'neutral',
#  '5b338d9c18248d8b6c9653f0': 'neutral',
#  '5b338d9e18248d8b6c96613e': 'neutral',
#  '5b338da018248d8b6c96704a': 'joy',
#  '5b338dc1dd60b8bb6b466aa7': 'joy',
#  '5b338dc1dd60b8bb6b466b81': 'joy',
#  '5b338dc2dd60b8bb6b466d4c': 'neutral',
#  '5b338dc4dd60b8bb6b467e62': 'joy',
#  '5b338dc4dd60b8bb6b4680b2': 'love/sadness',
#  '5b338dc5dd60b8bb6b46882f': 'joy',
#  '5b338dc6dd60b8bb6b4688c0': 'joy',
#  '5b338dc6dd60b8bb6b468a72': 'neutral',
#  '5b338dc6dd60b8bb6b468f23': 'joy',
#  '5b338dc7dd60b8bb6b4690e5': 'joy',
#  '5b338dc7dd60b8bb6b469159': 'joy/hope',
#  '5b338dc7dd60b8bb6b469549': 'joy',
#  '5b338dc8dd60b8bb6b469b96': 'neutral',
#  '5b338dc9dd60b8bb6b46a04d': 'neutral',
#  '5b338dc9dd60b8bb6b46a2be': 'neutral',
#  '5b338de9a67e600911c7d6a7': 'joy',
#  '5b338deaa67e600911c7d781': 'joy',
#  '5b338deaa67e600911c7d94c': 'neutral',
#  '5b338deca67e600911c7ea62': 'joy',
#  '5b338deda67e600911c7ecb2': 'love/sadness',
#  '5b338deea67e600911c7f42f': 'joy',
#  '5b338deea67e600911c7f4c0': 'joy',
#  '5b338deea67e600911c7f672': 'neutral',
#  '5b338defa67e600911c7fb23': 'joy',
#  '5b338defa67e600911c7fce5': 'joy',
#  '5b338defa67e600911c7fd59': 'joy/hope',
#  '5b338df0a67e600911c80149': 'joy',
#  '5b338df1a67e600911c80796': 'neutral',
#  '5b338df2a67e600911c80c4d': 'neutral',
#  '5b338df2a67e600911c80ebe': 'neutral',
#  '5b338df3a67e600911c8132c': 'love',
#  '5b338df3a67e600911c8162f': 'neutral',
#  '5b338df4a67e600911c81b11': 'neutral',
#  '5b338df5a67e600911c820cc': 'neutral',
#  '5b338df7a67e600911c82e1a': 'neutral',
#  '5b338e121d31d327ec851cf5': 'joy',
#  '5b338e121d31d327ec851dcf': 'joy',
#  '5b338e131d31d327ec851f9a': 'neutral',
#  '5b338e181d31d327ec8530b0': 'joy',
#  '5b338e191d31d327ec853300': 'love/sadness',
#  '5b338e1f1d31d327ec853a7d': 'joy',
#  '5b338e1f1d31d327ec853b0e': 'joy',
#  '5b338e211d31d327ec853cc0': 'neutral',
#  '5b338e251d31d327ec854171': 'joy',
#  '5b338e261d31d327ec854333': 'joy',
#  '5b338e261d31d327ec8543a7': 'joy/hope',
#  '5b338e291d31d327ec854797': 'joy',
#  '5b338e2e1d31d327ec854de4': 'neutral',
#  '5b338e321d31d327ec85529b': 'neutral',
#  '5b338e341d31d327ec85550c': 'neutral',
#  '5b338e371d31d327ec85597a': 'love',
#  '5b33972489eb16c8e73c9c79': 'joy',
#  '5b33972489eb16c8e73c9d53': 'joy',
#  '5b33972489eb16c8e73c9f1e': 'neutral',
#  '5b33972789eb16c8e73cb034': 'joy',
#  '5b33972789eb16c8e73cb284': 'love/sadness',
#  '5b33972889eb16c8e73cba01': 'joy',
#  '5b33972889eb16c8e73cba92': 'joy',
#  '5b33972889eb16c8e73cbc44': 'neutral',
#  '5b33972989eb16c8e73cc0f5': 'joy',
#  '5b34bc3a54127b2bacba86c2': 'neutral',
#  '5b34bc3b54127b2bacba8a1d': 'neutral',
#  '5b34bc3b54127b2bacba8cd5': 'neutral',
#  '5b34bc3b54127b2bacba8cf7': 'neutral',
#  '5b34bc3b54127b2bacba8f67': 'hope',
#  '5b34bc3b54127b2bacba9719': 'neutral',
#  '5b34bc3c54127b2bacba9cea': 'neutral',
#  '5b34bc3c54127b2bacba9cf3': 'neutral',
#  '5b34bc3c54127b2bacbaa153': 'neutral',
#  '5b34bc3c54127b2bacbaa631': 'hope',
#  '5b34bc3d54127b2bacbaa7ce': 'joy',
#  '5b34bc3d54127b2bacbaa826': 'neutral',
#  '5b34bc3d54127b2bacbaa8a2': 'neutral',
#  '5b34bc3d54127b2bacbaadcd': 'neutral',
#  '5b34bc3d54127b2bacbab372': 'neutral',
#  '5b34bc3d54127b2bacbab539': 'neutral',
#  '5b34bc3d54127b2bacbab5ef': 'neutral',
#  '5b34bc3d54127b2bacbab640': 'neutral',
#  '5b34bc3d54127b2bacbab8f2': 'neutral',
#  '5b34bc3e54127b2bacbac0f3': 'neutral',
#  '5b34bc3f54127b2bacbaca55': 'neutral',
#  '5b34bc3f54127b2bacbaca78': 'neutral',
#  '5b34bc3f54127b2bacbacbbb': 'neutral',
#  '5b34bc3f54127b2bacbacc15': 'neutral',
#  '5b34bc3f54127b2bacbad435': 'anger',
#  '5b34bc3f54127b2bacbad844': 'love',
#  '5b34bc3f54127b2bacbad902': 'neutral',
#  '5b34bc4054127b2bacbadb8a': 'hope',
#  '5b34bc4054127b2bacbadbb5': 'joy',
#  '5b34bc4054127b2bacbaddcf': 'neutral',
#  ...}

# %%
list_sent_pred_en = list()
for e in dict_id_sent_en.values():
    list_sent_pred_en.append(e)

# %%
list_sent_pred_ru = list()
for e in dict_id_sent_ru.values():
    list_sent_pred_ru.append(e)

# %%
lat_en = []
lon_en = []
for i in range(0, len(coord_en)):
    lon_en.append(coord_en[i][1])
    lat_en.append(coord_en[i][0])

df_lat_en = pd.DataFrame({'Lat': lat_en})
df_lon_en = pd.DataFrame({'Lon': lon_en})
result_en = pd.concat([df_lat_en, df_lon_en], axis = 1)

# %%
result_en.to_csv("gps_fifa.csv")

# %%
result_en
# Out:
#             Lat        Lon
# 0     59.950000  30.316700
# 1     55.772550  37.618980
# 2     59.950000  30.316700
# 3     55.714280  37.563220
# 4     59.950000  30.316700
# 5      6.466786   3.491592
# 6      5.027335   7.904663
# 7     59.934047  30.305950
# 8     59.950000  30.316700
# 9     54.827049  55.042319
# 10    59.842700  30.321900
# 11    59.950000  30.316700
# 12    58.865350  42.613687
# 13    59.950000  30.316700
# 14    59.940000  30.328611
# 15    59.925440  30.295940
# 16    55.715833  37.553611
# 17    41.691828  -8.834410
# 18    55.715833  37.553611
# 19    59.950000  30.316700
# 20    59.950000  30.316700
# 21    55.772550  37.618980
# 22    59.950000  30.316700
# 23    59.950000  30.316700
# 24    55.772550  37.618980
# 25    59.950000  30.316700
# 26    55.714280  37.563220
# 27    59.950000  30.316700
# 28     6.466786   3.491592
# 29     5.027335   7.904663
# ...         ...        ...
# 2335  43.585300  39.720300
# 2336  59.931046  30.360478
# 2337  59.931046  30.360478
# 2338  59.950000  30.316700
# 2339  55.850650  37.573242
# 2340  -0.024400  37.903900
# 2341  59.931046  30.360478
# 2342  55.818837  49.158497
# 2343  59.950000  30.316667
# 2344  56.832537  60.573523
# 2345  59.931046  30.360478
# 2346  43.402085  39.955773
# 2347  55.754167  37.620000
# 2348  55.850650  37.573242
# 2349  43.402004  39.955755
# 2350  43.402004  39.955755
# 2351  59.934100  30.306200
# 2352  59.925000  30.362200
# 2353  59.931046  30.360478
# 2354  55.850650  37.573242
# 2355  59.932460  30.345540
# 2356  59.934100  30.306200
# 2357  59.931046  30.360478
# 2358  59.931046  30.360478
# 2359  59.931046  30.360478
# 2360  55.817690  37.440550
# 2361  56.328872  43.986624
# 2362  59.931046  30.360478
# 2363  59.931046  30.360478
# 2364  55.818837  49.158497
#
# [2365 rows x 2 columns]

# %%
gps_en = []
for i in range(0,len(result_en)):   
    gps_en.append([result_en.Lat[i], result_en.Lon[i]])
gps_en
# Out:
# [[59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [-2.0053689, 30.0892638],
#  [59.95, 30.3167],
#  [26.27008, -80.25919],
#  [26.27008, -80.25919],
#  [5.65638696, -0.15742693],
#  [-23.08638889, -46.95055556],
#  [59.9404, 30.3139],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [-2.0053689, 30.0892638],
#  [59.95, 30.3167],
#  [26.27008, -80.25919],
#  [26.27008, -80.25919],
#  [5.65638696, -0.15742693],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [-2.0053689, 30.0892638],
#  [59.95, 30.3167],
#  [26.27008, -80.25919],
#  [26.27008, -80.25919],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [-2.0053689, 30.0892638],
#  [59.95, 30.3167],
#  [26.27008, -80.25919],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [-2.0053689, 30.0892638],
#  [59.95, 30.3167],
#  [26.27008, -80.25919],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [-2.0053689, 30.0892638],
#  [59.95, 30.3167],
#  [26.27008, -80.25919],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [-2.0053689, 30.0892638],
#  [59.95, 30.3167],
#  [26.27008, -80.25919],
#  [26.27008, -80.25919],
#  [5.65638696, -0.15742693],
#  [-23.08638889, -46.95055556],
#  [59.9404, 30.3139],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [59.95, 30.3167],
#  [55.77255, 37.61898],
#  [59.95, 30.3167],
#  [55.71428, 37.56322],
#  [59.95, 30.3167],
#  [6.46678646, 3.49159241],
#  [5.02733492, 7.90466309],
#  [59.934047, 30.30595],
#  [59.95, 30.3167],
#  [54.82704884, 55.042319],
#  [59.8427, 30.3219],
#  [59.95, 30.3167],
#  [58.86535022, 42.61368749],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.92544, 30.29594],
#  [55.71583333, 37.55361111],
#  [41.691828, -8.83441],
#  [55.71583333, 37.55361111],
#  [59.95, 30.3167],
#  [35.0, 135.75],
#  [59.941158, 30.326188],
#  [25.8081, -80.3533],
#  [-2.0053689, 30.0892638],
#  [59.95, 30.3167],
#  [26.27008, -80.25919],
#  [26.27008, -80.25919],
#  [5.65638696, -0.15742693],
#  [-23.08638889, -46.95055556],
#  [59.9404, 30.3139],
#  [55.7522, 37.6156],
#  [31.99645402, 35.83766078],
#  [49.574515, 10.915582],
#  [10.2851985, 11.1780713],
#  [55.71813, 37.57155],
#  [55.75583333, 37.61777778],
#  [1.36068237, 103.81569702],
#  [55.71565318, 37.55386591],
#  [59.95, 30.3167],
#  [-7.7659226, 110.3825003],
#  [43.402267, 39.956111],
#  [55.71565318, 37.55386591],
#  [5.0382789, 7.91564941],
#  [53.2768919, -2.8908183],
#  [59.95, 30.3167],
#  [59.93668731, 30.327165],
#  [26.11945, -80.1348],
#  [59.95, 30.31666667],
#  [59.93856502, 30.31537515],
#  [39.880452, 32.881993],
#  [55.7522, 37.6156],
#  [59.95, 30.3167],
#  [55.7522, 37.6156],
#  [10.7141781, 122.5514351],
#  [-0.0244, 37.9039],
#  [35.6608336, 139.7329239],
#  [41.49939, -81.70064],
#  [59.4615, 108.8318],
#  [59.4615, 108.8318],
#  [59.4615, 108.8318],
#  [47.5667, 7.6],
#  [61.52401, 105.318756],
#  [26.2527266, 78.1430813],
#  [59.95, 30.31666667],
#  [19.3158277, 84.8527025],
#  [-7.84682187, 110.13265621],
#  [59.95, 30.3167],
#  [59.95, 30.31666667],
#  [59.93585717, 30.35471209],
#  [4.78857447, 7.05322266],
#  [59.95, 30.317],
#  [55.71583333, 37.55361111],
#  [6.55956752, 3.35083008],
#  [4.76667816, 7.07519531],
#  [9.10616471, 7.40478516],
#  [59.9314819, 30.3129195],
#  [9.10616471, 7.3828125],
#  [51.5103298, -0.1293701],
#  [55.71573883, 37.55386514],
#  [59.94110535, 30.32548428],
#  [59.94110535, 30.32548428],
#  [59.96009716, 30.3211825],
#  [59.95, 30.3167],
#  [59.94110535, 30.32548428],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [5.0382789, 7.92114258],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.95, 30.317],
#  [59.94339, 30.306842],
#  [59.95, 30.3167],
#  [43.69466441, 7.25814658],
#  [59.93922, 30.35128],
#  [55.7522, 37.6156],
#  [38.87360155, -77.37332907],
#  [59.98169598, 30.1991961],
#  [59.95, 30.31666667],
#  [51.48217862, -0.18016398],
#  [55.852472, -4.309626],
#  [59.93284, 30.30358],
#  [43.6541, -79.42319],
#  [55.53811, 37.36294],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [33.5833, 130.4],
#  [59.93994073, 30.32047214],
#  [55.53811, 37.36294],
#  [59.95000394, 30.31668131],
#  [59.95, 30.31666667],
#  [59.95, 30.3167],
#  [33.89059, -118.1705],
#  [59.93428, 30.335099],
#  [59.9342802, 30.3350986],
#  [39.96206, -75.14142],
#  [59.9342802, 30.3350986],
#  [59.9342802, 30.3350986],
#  [59.9342802, 30.3350986],
#  [41.476, -74.0281],
#  [59.9342802, 30.3350986],
#  [59.9342802, 30.3350986],
#  [59.9342802, 30.3350986],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.92803, 30.37373],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.9342802, 30.3350986],
#  [59.9342802, 30.3350986],
#  [59.9390557, 30.31612768],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [52.210569, 21.021937],
#  [59.9342802, 30.3350986],
#  [59.95, 30.3167],
#  [59.9342802, 30.3350986],
#  [59.91021283, 30.4851199],
#  [59.95, 30.3167],
#  [59.9342802, 30.3350986],
#  [60.05860361, 30.46797185],
#  [59.93751, 30.29022],
#  [55.7522, 37.6156],
#  [55.7522, 37.6156],
#  [59.94567, 30.26498],
#  [55.7522, 37.6156],
#  [59.95, 30.3167],
#  [55.7522, 37.6156],
#  [55.53811, 37.36294],
#  [59.94099209, 30.31358202],
#  [59.95, 30.3167],
#  [59.96907401, 30.31579083],
#  [59.95, 30.3167],
#  [59.81459415, 30.4404782],
#  [59.95, 30.31666667],
#  [59.93212178, 30.23402388],
#  [59.95, 30.3167],
#  [59.96907401, 30.31579083],
#  [59.95, 30.31666667],
#  [43.402267, 39.956111],
#  [59.95, 30.3167],
#  [59.97301135, 30.22032022],
#  [56.83765, 60.59891],
#  [59.95, 30.3167],
#  [59.96907401, 30.31579083],
#  [33.8197, -84.3281],
#  [59.96907401, 30.31579083],
#  [59.99291365, 30.1538873],
#  [59.95, 30.3167],
#  [59.96907401, 30.31579083],
#  [59.96907401, 30.31579083],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.97293924, 30.22063694],
#  [59.95, 30.3167],
#  [55.75583333, 37.61777778],
#  [59.95, 30.3167],
#  [55.75583333, 37.61777778],
#  [59.97293924, 30.22063694],
#  [55.7522, 37.6156],
#  [59.93535471, 30.32360673],
#  [59.95, 30.3167],
#  [59.96907401, 30.31579083],
#  [59.97133, 30.22649],
#  [43.402267, 39.956111],
#  [59.97293924, 30.22063694],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.94, 30.32861111],
#  [59.95, 30.3167],
#  [59.9251, 30.3614],
#  [59.8683249, 30.4640678],
#  [5.57635019, 5.80078125],
#  [59.94100992, 30.41089893],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.97301135, 30.22032022],
#  [59.97293924, 30.22063694],
#  [25.8081, -80.3533],
#  [59.95, 30.3167],
#  [-26.15971666, 27.99121745],
#  [59.94, 30.32861111],
#  [59.95027778, 30.29194444],
#  [59.97293924, 30.22063694],
#  [59.95, 30.3167],
#  [59.97293924, 30.22063694],
#  [59.84406667, 30.32676333],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.97293924, 30.22063694],
#  [59.97293924, 30.22063694],
#  [59.95, 30.3167],
#  [43.402267, 39.956111],
#  [48.1628, 11.4471],
#  [59.8419916, 30.346924],
#  [48.13797595, 11.56915959],
#  [59.95, 30.3167],
#  [59.93233514, 30.35495055],
#  [59.95, 30.31666667],
#  [59.4615, 108.8318],
#  [59.97295278, 30.22053333],
#  [59.92838, 30.30052],
#  [59.97293924, 30.22063694],
#  [59.93668731, 30.327165],
#  [59.9419004, 30.37838864],
#  [59.95, 30.3167],
#  [59.92576389, 30.39578889],
#  [59.95, 30.3167],
#  [59.95, 30.3167],
#  [59.79968443, 30.27239799],
#  [59.98169598, 30.1991961],
#  [59.93235889, 30.40325755],
#  [59.95, 30.3167],
#  [43.402267, 39.956111],
#  [59.94732142, 30.33849466],
#  [4.74478115, 7.05322266],
#  [59.93271, 30.2982],
#  ...]

# %%
color_sent = []
def color_map(sentiment):
    for i in range(len(sentiment)):
        if sentiment[i] == "neutral":
            color_sent.append(str("grey"))
        elif sentiment[i] == "joy":
            color_sent.append(str("orange"))
        elif sentiment[i] == "anger":
            color_sent.append(str("crimson"))
        elif sentiment[i] == "love":
            color_sent.append(str("red"))
        elif sentiment[i] == "sadness":
            color_sent.append(str("black"))
        elif sentiment[i] == "hope":
            color_sent.append(str("yellow"))  
        elif sentiment[i] == "joy/hope":
            color_sent.append(str("green")) 
        elif sentiment[i] == "love/sadness":
            color_sent.append(str("purple")) 
    return color_sent

# %%
color = color_map(list_sent_pred)

# %%
len(color)
# Out:
# 2365

# %%
mapit = None
fond = r'http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png'
mapit = folium.Map(location=[59.9386300,30.3141300], zoom_start=6, tiles=fond, attr='Â© OpenStreetMap Â© CartoDB')

for i in range(len(gps_en)):
    
    folium.CircleMarker( location=[ gps_en[i][0], gps_en[i][1] ], radius = 4,  color = color[i], fill = True, fill_color = color[i]).add_to( mapit )

# %%
mapit.save("map.html")
